# %% [markdown]
# # Exploratory Data Analysis
#
# In this notebook, we explore our dataset and make some visualizations.
#
# We analize the data with pandas, and for the plots we use matplotlib and seaborn.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# We load the data

# %%
df=pd.read_csv('/home/maggie/BGA_games_recommender/1.Data_Collection/BGA_BGG_complete.csv',index_col=0)

# %%
print('At the moment we collect information of ' + str(df.shape[0]) + ' Board Game Arena games, that are indexed in BGG.')
# Out:
# At the moment we collect information of 448 Board Game Arena games, that are indexed in BGG.

# %%
df.head()
# Out:
#                                 url            Name          Nombre  GameID  \
# 0              /gamepanel?game=azul            Azul            Azul  230802
# 1       /gamepanel?game=carcassonne     Carcassonne     Carcassonne     822
# 2          /gamepanel?game=splendor        Splendor        Splendor  148228
# 3  /gamepanel?game=sevenwondersduel  7 Wonders Duel  7 Wonders Duel  173346
# 4          /gamepanel?game=agricola        Agricola        Agrícola  200680
#
#                                            Thumbnail  \
# 0  https://cf.geekdo-images.com/tz19PfklMdAdjxV9W...
# 1  https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...
# 2  https://cf.geekdo-images.com/rwOMxx4q5yuElIvo-...
# 3  https://cf.geekdo-images.com/WzNs1mA_o22ZWTR8f...
# 4  https://cf.geekdo-images.com/Vf_0TrTfz9yll7rVB...
#
#                                          Description  Year  Min_players  \
# 0  Introduced by the Moors, azulejos (originally ...  2017            2
# 1  Carcassonne is a tile-placement game in which ...  2000            2
# 2  Splendor is a game of chip-collecting and card...  2014            2
# 3  In many ways 7 Wonders Duel resembles its pare...  2015            2
# 4  Updated and streamlined for a new generation o...  2016            1
#
#    Max_players  Playing_time  ...  Mechanic: King of the Hill  \
# 0            4            45  ...                         NaN
# 1            5            45  ...                         NaN
# 2            4            30  ...                         NaN
# 3            2            30  ...                         NaN
# 4            4           120  ...                         NaN
#
#    Mechanic: Action/Event  Mechanic: Targeted Clues  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#    Mechanic: Stacking and Balancing  Mechanic: Card Play Conflict Resolution  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    Category: Real-time Mechanic: Speed Matching  \
# 0                  NaN                      NaN
# 1                  NaN                      NaN
# 2                  NaN                      NaN
# 3                  NaN                      NaN
# 4                  NaN                      NaN
#
#   Mechanic: Narrative Choice / Paragraph  Mechanic: Measurement Movement  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
#
#    Mechanic: Movement Template
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 235 columns]

# %% [markdown]
# The columns of the dataframe are:

# %%
df.columns.values
# Out:
# array(['url', 'Name', 'Nombre', 'GameID', 'Thumbnail', 'Description',
#        'Year', 'Min_players', 'Max_players', 'Playing_time',
#        'Category: Deduction', 'Category: Memory',
#        'Category: Murder/Mystery', 'Mechanic: Action Points',
#        'Mechanic: Hand Management', 'Mechanic: Memory', 'Designer',
#        'Artist', 'Average_rating', 'Users_rated', 'Bayes_average_rating',
#        'Average_weight', 'Category: Card Game', 'Category: Number',
#        'Mechanic: Kill Steal', 'Mechanic: Score-and-Reset Game',
#        'Mechanic: Simultaneous Action Selection', 'Category: Ancient',
#        'Category: City Building', 'Category: Civilization',
#        'Category: Economic', 'Mechanic: Closed Drafting',
#        'Mechanic: Set Collection', 'Mechanic: Variable Player Powers',
#        'Mechanic: Layering', 'Mechanic: Open Drafting',
#        'Mechanic: Sudden Death Ending', 'Mechanic: Tug of War',
#        'Category: Fantasy', 'Category: Fighting',
#        'Mechanic: Action Queue', 'Mechanic: Team-Based Game',
#        'Category: Abstract Strategy', 'Mechanic: Grid Movement',
#        'Mechanic: Hexagon Grid', 'Mechanic: Slide/Push',
#        'Mechanic: Static Capture', 'Category: Farming',
#        'Mechanic: Deck, Bag, and Pool Building', 'Category: Mythology',
#        'Category: Science Fiction', 'Mechanic: Auction/Bidding',
#        'Mechanic: Push Your Luck', 'Category: Animals',
#        'Mechanic: Enclosure', 'Mechanic: Worker Placement',
#        'Mechanic: Advantage Token', 'Mechanic: Automatic Resource Growth',
#        'Mechanic: Increase Value of Unchosen Resources',
#        'Mechanic: Solo / Solitaire Game',
#        'Mechanic: Turn Order: Claim Action', 'Category: Arabian',
#        'Category: Medieval', 'Mechanic: Tile Placement',
#        'Mechanic: Area Majority / Influence', 'Category: Zombies',
#        'Category: American West', 'Category: Bluffing',
#        'Category: Territory Building', 'Mechanic: Secret Unit Deployment',
#        'Category: Racing', 'Category: Sports', 'Category: Transportation',
#        'Mechanic: Race', 'Category: Dice',
#        'Mechanic: Betting and Bluffing', 'Mechanic: Dice Rolling',
#        'Mechanic: Roll / Spin and Move', 'Mechanic: Track Movement',
#        'Category: Video Game Theme', 'Mechanic: Paper-and-Pencil',
#        'Mechanic: Re-rolling and Locking', 'Mechanic: Cooperative Game',
#        'Mechanic: Network and Route Building', 'Mechanic: Hidden Roles',
#        'Mechanic: Player Elimination', 'Mechanic: Take That',
#        'Mechanic: Trick-taking', 'Category: Wargame',
#        'Category: World War II', 'Category: Print & Play',
#        'Mechanic: Modular Board', "Category: Children's Game",
#        'Category: Nautical', 'Category: Space Exploration',
#        'Mechanic: Action Drafting', 'Mechanic: Contracts',
#        'Mechanic: Events', 'Mechanic: Point to Point Movement',
#        'Mechanic: Tech Trees / Tech Tracks',
#        'Mechanic: Auction: Once Around', 'Mechanic: Simulation',
#        'Mechanic: Matching', 'Category: Aviation / Flight',
#        'Mechanic: Investment', 'Mechanic: Pattern Movement',
#        'Mechanic: Square Grid', 'Mechanic: Pick-up and Deliver',
#        'Category: Travel', 'Category: Mafia',
#        'Mechanic: Pattern Building', 'Mechanic: Loans',
#        'Mechanic: Map Addition', 'Category: Prehistoric',
#        'Category: Industry / Manufacturing', 'Mechanic: Action Retrieval',
#        'Mechanic: Area Movement', 'Mechanic: Connections',
#        'Mechanic: End Game Bonuses', 'Mechanic: Follow',
#        'Mechanic: Income', 'Mechanic: Movement Points',
#        'Mechanic: Resource to Move', 'Mechanic: Turn Order: Progressive',
#        'Mechanic: Variable Phase Order',
#        'Mechanic: Worker Placement, Different Worker Types',
#        'Mechanic: Grid Coverage', 'Mechanic: Turn Order: Stat-Based',
#        'Mechanic: Variable Set-up',
#        'Mechanic: Worker Placement with Dice Workers',
#        'Mechanic: Ownership', 'Mechanic: Turn Order: Pass Order',
#        'Category: Adventure', 'Mechanic: Hidden Victory Points',
#        'Category: Comic Book / Strip', 'Category: Educational',
#        'Mechanic: Commodity Speculation', 'Mechanic: Stock Holding',
#        'Mechanic: Market', 'Category: Environmental', 'Category: Puzzle',
#        'Category: Trains', 'Mechanic: Programmed Movement',
#        'Mechanic: Command Cards', 'Category: Party Game',
#        'Mechanic: Communication Limits', 'Category: Political',
#        'Mechanic: Scenario / Mission / Campaign Game',
#        'Category: Spies/Secret Agents', 'Mechanic: Voting',
#        'Mechanic: Deduction', 'Mechanic: Trading',
#        'Category: Exploration', 'Mechanic: Move Through Deck',
#        'Mechanic: Random Production', 'Category: Medical',
#        'Mechanic: Pattern Recognition', 'Mechanic: Bingo',
#        'Category: Humor', 'Mechanic: Moving Multiple Units',
#        'Mechanic: Predictive Bid', 'Category: Maze',
#        'Mechanic: Map Deformation', 'Mechanic: Rock-Paper-Scissors',
#        'Category: Math', 'Mechanic: Victory Points as a Resource',
#        'Category: Renaissance', 'Mechanic: Auction: Sealed Bid',
#        'Mechanic: Auction: Turn Order Until Pass',
#        'Mechanic: Selection Order Bid', 'Mechanic: Map Reduction',
#        'Category: Post-Napoleonic', 'Mechanic: Mancala',
#        'Mechanic: Catch the Leader', 'Mechanic: Ladder Climbing',
#        'Category: Word Game', 'Mechanic: Delayed Purchase',
#        'Category: Movies / TV / Radio theme', 'Mechanic: Pieces as Map',
#        'Mechanic: Three Dimensional Movement',
#        'Mechanic: Auction: Fixed Placement',
#        'Mechanic: Constrained Bidding', 'Mechanic: Melding and Splaying',
#        'Category: Novel-based', 'Mechanic: Multiple-Lot Auction',
#        'Mechanic: Turn Order: Auction', 'Mechanic: Multiple Maps',
#        'Mechanic: Chaining', 'Category: Collectible Components',
#        'Category: Miniatures', 'Mechanic: Critical Hits and Failures',
#        'Mechanic: Line of Sight', 'Mechanic: Zone of Control',
#        'Category: Pirates', 'Mechanic: Turn Order: Role Order',
#        'Mechanic: Area-Impulse', 'Mechanic: Once-Per-Game Abilities',
#        'Mechanic: Bias', 'Mechanic: Closed Economy Auction',
#        'Mechanic: Single Loser Game', 'Mechanic: Time Track',
#        'Mechanic: I Cut, You Choose', 'Mechanic: Line Drawing',
#        'Mechanic: Different Dice Movement', 'Mechanic: Acting',
#        'Mechanic: Storytelling', 'Category: Horror',
#        'Category: Negotiation', 'Mechanic: Traitor Game',
#        'Category: Age of Reason', 'Category: Religious',
#        'Mechanic: Auction: Dutch', 'Mechanic: Lose a Turn',
#        'Mechanic: Auction: Dutch Priority', 'Mechanic: Deck Construction',
#        'Category: Game System', 'Mechanic: Highest-Lowest Scoring',
#        'Mechanic: Rondel', 'Mechanic: Campaign / Battle Card Driven',
#        'Mechanic: Ratio / Combat Results Table', 'Mechanic: Role Playing',
#        'Category: Music', 'Mechanic: Negotiation',
#        'Mechanic: Player Judge', 'Mechanic: Die Icon Resolution',
#        'Mechanic: King of the Hill', 'Mechanic: Action/Event',
#        'Mechanic: Targeted Clues', 'Mechanic: Stacking and Balancing',
#        'Mechanic: Card Play Conflict Resolution', 'Category: Real-time',
#        'Mechanic: Speed Matching',
#        'Mechanic: Narrative Choice / Paragraph',
#        'Mechanic: Measurement Movement', 'Mechanic: Movement Template'],
#       dtype=object)

# %% [markdown]
# ### Missing values

# %% [markdown]
# We check if the dataframe has missing values.

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# Let's see which columns have missing values.

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Category: Deduction',
#  'Category: Memory',
#  'Category: Murder/Mystery',
#  'Mechanic: Action Points',
#  'Mechanic: Hand Management',
#  'Mechanic: Memory',
#  'Category: Card Game',
#  'Category: Number',
#  'Mechanic: Kill Steal',
#  'Mechanic: Score-and-Reset Game',
#  'Mechanic: Simultaneous Action Selection',
#  'Category: Ancient',
#  'Category: City Building',
#  'Category: Civilization',
#  'Category: Economic',
#  'Mechanic: Closed Drafting',
#  'Mechanic: Set Collection',
#  'Mechanic: Variable Player Powers',
#  'Mechanic: Layering',
#  'Mechanic: Open Drafting',
#  'Mechanic: Sudden Death Ending',
#  'Mechanic: Tug of War',
#  'Category: Fantasy',
#  'Category: Fighting',
#  'Mechanic: Action Queue',
#  'Mechanic: Team-Based Game',
#  'Category: Abstract Strategy',
#  'Mechanic: Grid Movement',
#  'Mechanic: Hexagon Grid',
#  'Mechanic: Slide/Push',
#  'Mechanic: Static Capture',
#  'Category: Farming',
#  'Mechanic: Deck, Bag, and Pool Building',
#  'Category: Mythology',
#  'Category: Science Fiction',
#  'Mechanic: Auction/Bidding',
#  'Mechanic: Push Your Luck',
#  'Category: Animals',
#  'Mechanic: Enclosure',
#  'Mechanic: Worker Placement',
#  'Mechanic: Advantage Token',
#  'Mechanic: Automatic Resource Growth',
#  'Mechanic: Increase Value of Unchosen Resources',
#  'Mechanic: Solo / Solitaire Game',
#  'Mechanic: Turn Order: Claim Action',
#  'Category: Arabian',
#  'Category: Medieval',
#  'Mechanic: Tile Placement',
#  'Mechanic: Area Majority / Influence',
#  'Category: Zombies',
#  'Category: American West',
#  'Category: Bluffing',
#  'Category: Territory Building',
#  'Mechanic: Secret Unit Deployment',
#  'Category: Racing',
#  'Category: Sports',
#  'Category: Transportation',
#  'Mechanic: Race',
#  'Category: Dice',
#  'Mechanic: Betting and Bluffing',
#  'Mechanic: Dice Rolling',
#  'Mechanic: Roll / Spin and Move',
#  'Mechanic: Track Movement',
#  'Category: Video Game Theme',
#  'Mechanic: Paper-and-Pencil',
#  'Mechanic: Re-rolling and Locking',
#  'Mechanic: Cooperative Game',
#  'Mechanic: Network and Route Building',
#  'Mechanic: Hidden Roles',
#  'Mechanic: Player Elimination',
#  'Mechanic: Take That',
#  'Mechanic: Trick-taking',
#  'Category: Wargame',
#  'Category: World War II',
#  'Category: Print & Play',
#  'Mechanic: Modular Board',
#  "Category: Children's Game",
#  'Category: Nautical',
#  'Category: Space Exploration',
#  'Mechanic: Action Drafting',
#  'Mechanic: Contracts',
#  'Mechanic: Events',
#  'Mechanic: Point to Point Movement',
#  'Mechanic: Tech Trees / Tech Tracks',
#  'Mechanic: Auction: Once Around',
#  'Mechanic: Simulation',
#  'Mechanic: Matching',
#  'Category: Aviation / Flight',
#  'Mechanic: Investment',
#  'Mechanic: Pattern Movement',
#  'Mechanic: Square Grid',
#  'Mechanic: Pick-up and Deliver',
#  'Category: Travel',
#  'Category: Mafia',
#  'Mechanic: Pattern Building',
#  'Mechanic: Loans',
#  'Mechanic: Map Addition',
#  'Category: Prehistoric',
#  'Category: Industry / Manufacturing',
#  'Mechanic: Action Retrieval',
#  'Mechanic: Area Movement',
#  'Mechanic: Connections',
#  'Mechanic: End Game Bonuses',
#  'Mechanic: Follow',
#  'Mechanic: Income',
#  'Mechanic: Movement Points',
#  'Mechanic: Resource to Move',
#  'Mechanic: Turn Order: Progressive',
#  'Mechanic: Variable Phase Order',
#  'Mechanic: Worker Placement, Different Worker Types',
#  'Mechanic: Grid Coverage',
#  'Mechanic: Turn Order: Stat-Based',
#  'Mechanic: Variable Set-up',
#  'Mechanic: Worker Placement with Dice Workers',
#  'Mechanic: Ownership',
#  'Mechanic: Turn Order: Pass Order',
#  'Category: Adventure',
#  'Mechanic: Hidden Victory Points',
#  'Category: Comic Book / Strip',
#  'Category: Educational',
#  'Mechanic: Commodity Speculation',
#  'Mechanic: Stock Holding',
#  'Mechanic: Market',
#  'Category: Environmental',
#  'Category: Puzzle',
#  'Category: Trains',
#  'Mechanic: Programmed Movement',
#  'Mechanic: Command Cards',
#  'Category: Party Game',
#  'Mechanic: Communication Limits',
#  'Category: Political',
#  'Mechanic: Scenario / Mission / Campaign Game',
#  'Category: Spies/Secret Agents',
#  'Mechanic: Voting',
#  'Mechanic: Deduction',
#  'Mechanic: Trading',
#  'Category: Exploration',
#  'Mechanic: Move Through Deck',
#  'Mechanic: Random Production',
#  'Category: Medical',
#  'Mechanic: Pattern Recognition',
#  'Mechanic: Bingo',
#  'Category: Humor',
#  'Mechanic: Moving Multiple Units',
#  'Mechanic: Predictive Bid',
#  'Category: Maze',
#  'Mechanic: Map Deformation',
#  'Mechanic: Rock-Paper-Scissors',
#  'Category: Math',
#  'Mechanic: Victory Points as a Resource',
#  'Category: Renaissance',
#  'Mechanic: Auction: Sealed Bid',
#  'Mechanic: Auction: Turn Order Until Pass',
#  'Mechanic: Selection Order Bid',
#  'Mechanic: Map Reduction',
#  'Category: Post-Napoleonic',
#  'Mechanic: Mancala',
#  'Mechanic: Catch the Leader',
#  'Mechanic: Ladder Climbing',
#  'Category: Word Game',
#  'Mechanic: Delayed Purchase',
#  'Category: Movies / TV / Radio theme',
#  'Mechanic: Pieces as Map',
#  'Mechanic: Three Dimensional Movement',
#  'Mechanic: Auction: Fixed Placement',
#  'Mechanic: Constrained Bidding',
#  'Mechanic: Melding and Splaying',
#  'Category: Novel-based',
#  'Mechanic: Multiple-Lot Auction',
#  'Mechanic: Turn Order: Auction',
#  'Mechanic: Multiple Maps',
#  'Mechanic: Chaining',
#  'Category: Collectible Components',
#  'Category: Miniatures',
#  'Mechanic: Critical Hits and Failures',
#  'Mechanic: Line of Sight',
#  'Mechanic: Zone of Control',
#  'Category: Pirates',
#  'Mechanic: Turn Order: Role Order',
#  'Mechanic: Area-Impulse',
#  'Mechanic: Once-Per-Game Abilities',
#  'Mechanic: Bias',
#  'Mechanic: Closed Economy Auction',
#  'Mechanic: Single Loser Game',
#  'Mechanic: Time Track',
#  'Mechanic: I Cut, You Choose',
#  'Mechanic: Line Drawing',
#  'Mechanic: Different Dice Movement',
#  'Mechanic: Acting',
#  'Mechanic: Storytelling',
#  'Category: Horror',
#  'Category: Negotiation',
#  'Mechanic: Traitor Game',
#  'Category: Age of Reason',
#  'Category: Religious',
#  'Mechanic: Auction: Dutch',
#  'Mechanic: Lose a Turn',
#  'Mechanic: Auction: Dutch Priority',
#  'Mechanic: Deck Construction',
#  'Category: Game System',
#  'Mechanic: Highest-Lowest Scoring',
#  'Mechanic: Rondel',
#  'Mechanic: Campaign / Battle Card Driven',
#  'Mechanic: Ratio / Combat Results Table',
#  'Mechanic: Role Playing',
#  'Category: Music',
#  'Mechanic: Negotiation',
#  'Mechanic: Player Judge',
#  'Mechanic: Die Icon Resolution',
#  'Mechanic: King of the Hill',
#  'Mechanic: Action/Event',
#  'Mechanic: Targeted Clues',
#  'Mechanic: Stacking and Balancing',
#  'Mechanic: Card Play Conflict Resolution',
#  'Category: Real-time',
#  'Mechanic: Speed Matching',
#  'Mechanic: Narrative Choice / Paragraph',
#  'Mechanic: Measurement Movement',
#  'Mechanic: Movement Template']

# %% [markdown]
# The only columns with missing values are the Category and Mechanic columns. A value of 1.0 in these columns means that the game belongs to that category or has that mechanic. So, we complete the missing values (all the missing values of the dataframe) with 0.0, and in this case means that the game does not belong to the category or does not have the mechanic.

# %%
df=df.fillna(0)

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Year of publication

# %% [markdown]
# Let's explore the year of publication. First we look which is the oldest game in BGA.

# %%
print('The oldest game in BGA is ' + df.loc[df.Year.idxmin()].Name +'. It is from the year ' + str(min(df.Year)) + '.')
# Out:
# The oldest game in BGA is Senet. It is from the year -3500.

# %% [markdown]
# Another old games:

# %%
df[['Name','Year']].sort_values('Year')[:30].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7c7c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7c7c_row0_col0" class="data row0 col0" >Senet</td>
#       <td id="T_a7c7c_row0_col1" class="data row0 col1" >-3500</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row1_col0" class="data row1 col0" >Backgammon</td>
#       <td id="T_a7c7c_row1_col1" class="data row1 col1" >-3000</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row2_col0" class="data row2 col0" >Go</td>
#       <td id="T_a7c7c_row2_col1" class="data row2 col1" >-2200</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row3_col0" class="data row3 col0" >Nine Men's Morris</td>
#       <td id="T_a7c7c_row3_col1" class="data row3 col1" >-1400</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row4_col0" class="data row4 col0" >Four Color Cards</td>
#       <td id="T_a7c7c_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row5_col0" class="data row5 col0" >Exploration: Warzone</td>
#       <td id="T_a7c7c_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row6_col0" class="data row6 col0" >Bao la Kiswahili</td>
#       <td id="T_a7c7c_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row7_col0" class="data row7 col0" >Tock</td>
#       <td id="T_a7c7c_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row8_col0" class="data row8 col0" >Bobail</td>
#       <td id="T_a7c7c_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row9_col0" class="data row9 col0" >Japanese (Riichi) Mahjong</td>
#       <td id="T_a7c7c_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row10_col0" class="data row10 col0" >Herooj</td>
#       <td id="T_a7c7c_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row11_col0" class="data row11 col0" >Evo: The “Game no Name”</td>
#       <td id="T_a7c7c_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row12_col0" class="data row12 col0" >Pedro</td>
#       <td id="T_a7c7c_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row13_col0" class="data row13 col0" >99 (addition card game)</td>
#       <td id="T_a7c7c_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row14_col0" class="data row14 col0" >Whist 22</td>
#       <td id="T_a7c7c_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row15_col0" class="data row15 col0" >Solo Whist</td>
#       <td id="T_a7c7c_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row16_col0" class="data row16 col0" >Yaniv</td>
#       <td id="T_a7c7c_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row17_col0" class="data row17 col0" >Koi-Koi</td>
#       <td id="T_a7c7c_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row18_col0" class="data row18 col0" >Palace</td>
#       <td id="T_a7c7c_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row19_col0" class="data row19 col0" >Gomoku</td>
#       <td id="T_a7c7c_row19_col1" class="data row19 col1" >700</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row20_col0" class="data row20 col0" >Kalah</td>
#       <td id="T_a7c7c_row20_col1" class="data row20 col1" >700</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row21_col0" class="data row21 col0" >Xiangqi</td>
#       <td id="T_a7c7c_row21_col1" class="data row21 col1" >762</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row22_col0" class="data row22 col0" >Checkers</td>
#       <td id="T_a7c7c_row22_col1" class="data row22 col1" >1150</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row23_col0" class="data row23 col0" >French Tarot</td>
#       <td id="T_a7c7c_row23_col1" class="data row23 col1" >1425</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row24_col0" class="data row24 col0" >Grosstarock</td>
#       <td id="T_a7c7c_row24_col1" class="data row24 col1" >1425</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row25_col0" class="data row25 col0" >Chess</td>
#       <td id="T_a7c7c_row25_col1" class="data row25 col1" >1475</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row26_col0" class="data row26 col0" >Scopa</td>
#       <td id="T_a7c7c_row26_col1" class="data row26 col1" >1600</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row27_col0" class="data row27 col0" >Caribbean All Fours</td>
#       <td id="T_a7c7c_row27_col1" class="data row27 col1" >1600</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row28_col0" class="data row28 col0" >Phat</td>
#       <td id="T_a7c7c_row28_col1" class="data row28 col1" >1600</td>
#     </tr>
#     <tr>
#       <td id="T_a7c7c_row29_col0" class="data row29 col0" >Cribbage</td>
#       <td id="T_a7c7c_row29_col1" class="data row29 col1" >1630</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We plot a histogram counting the games per year, for games that were published after 1950 (the mayority of the games)

# %%
df[df.Year>=1950].shape[0]
# Out:
# 400

# %%
df[df.Year<1950].shape[0]
# Out:
# 48

# %%
sns.histplot(df[df.Year>=1950].Year)
#discrete=True
plt.title('Year')
plt.show()

# %%
round(df[df.Year>=2010].shape[0]/df.shape[0]*100,2)
# Out:
# 70.31

# %% [markdown]
# Most of the games (more than 70%) were published after 2010.

# %% [markdown]
# ### Ratings

# %% [markdown]
# Now, let's explore the ratings of the games in BGA. We have to ratings: Average rating and Bayes average rating.
# Average rating is the average between the scores given by users. Bayes average rating is based on the average rating, but with some alterations (artificial mid range "dummy" votes are added) to prevent games with very few votes climbing to the top of BGG Rank. See more details in [Board Game Geek FAQ](https://boardgamegeek.com/wiki/page/BoardGameGeek_FAQ#toc13).

# %%
sns.histplot(df['Average_rating'],kde=True)
plt.title('Average rating')
plt.show()

# %%
sns.histplot(df['Bayes_average_rating'],kde=True)
plt.title('Bayes average rating')
plt.show()

# %% [markdown]
# Some games do not have bayes average rating yet.

# %%
sns.histplot(df[df.Bayes_average_rating>0]['Bayes_average_rating'],kde=True)
plt.title('Bayes average rating')
plt.show()

# %% [markdown]
# #### Top 10 games by average rating and by Bayes average rating

# %%
df.sort_values('Average_rating',ascending=False)[['Name','Average_rating']][:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6eab3_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6eab3_row0_col0" class="data row0 col0" >Gaia Project</td>
#       <td id="T_6eab3_row0_col1" class="data row0 col1" >8.464810</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row1_col0" class="data row1 col0" >The Crew: Mission Deep Sea</td>
#       <td id="T_6eab3_row1_col1" class="data row1 col1" >8.410630</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row2_col0" class="data row2 col0" >Ultimate Railroads</td>
#       <td id="T_6eab3_row2_col1" class="data row2 col1" >8.389980</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row3_col0" class="data row3 col0" >Through the Ages: A new Story of Civilization</td>
#       <td id="T_6eab3_row3_col1" class="data row3 col1" >8.373460</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row4_col0" class="data row4 col0" >Japanese (Riichi) Mahjong</td>
#       <td id="T_6eab3_row4_col1" class="data row4 col1" >8.279870</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row5_col0" class="data row5 col0" >A Feast for Odin</td>
#       <td id="T_6eab3_row5_col1" class="data row5 col1" >8.203180</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row6_col0" class="data row6 col0" >Unconditional Surrender! World War 2 in Europe</td>
#       <td id="T_6eab3_row6_col1" class="data row6 col1" >8.186240</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row7_col0" class="data row7 col0" >The Castles of Burgundy</td>
#       <td id="T_6eab3_row7_col1" class="data row7 col1" >8.126400</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row8_col0" class="data row8 col0" >Lost Ruins of Arnak</td>
#       <td id="T_6eab3_row8_col1" class="data row8 col1" >8.120830</td>
#     </tr>
#     <tr>
#       <td id="T_6eab3_row9_col0" class="data row9 col0" >Terra Mystica</td>
#       <td id="T_6eab3_row9_col1" class="data row9 col1" >8.115700</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sort_values('Bayes_average_rating',ascending=False)[['Name','Bayes_average_rating']][:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2abf7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Bayes_average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2abf7_row0_col0" class="data row0 col0" >Gaia Project</td>
#       <td id="T_2abf7_row0_col1" class="data row0 col1" >8.172740</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row1_col0" class="data row1 col0" >Through the Ages: A new Story of Civilization</td>
#       <td id="T_2abf7_row1_col1" class="data row1 col1" >8.141050</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row2_col0" class="data row2 col0" >The Castles of Burgundy</td>
#       <td id="T_2abf7_row2_col1" class="data row2 col1" >8.006360</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row3_col0" class="data row3 col0" >7 Wonders Duel</td>
#       <td id="T_2abf7_row3_col1" class="data row3 col1" >7.983320</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row4_col0" class="data row4 col0" >Terra Mystica</td>
#       <td id="T_2abf7_row4_col1" class="data row4 col1" >7.958420</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row5_col0" class="data row5 col0" >A Feast for Odin</td>
#       <td id="T_2abf7_row5_col1" class="data row5 col1" >7.952880</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row6_col0" class="data row6 col0" >Lost Ruins of Arnak</td>
#       <td id="T_2abf7_row6_col1" class="data row6 col1" >7.861380</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row7_col0" class="data row7 col0" >Puerto Rico</td>
#       <td id="T_2abf7_row7_col1" class="data row7 col1" >7.830930</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row8_col0" class="data row8 col0" >Blood Rage</td>
#       <td id="T_2abf7_row8_col1" class="data row8 col1" >7.812070</td>
#     </tr>
#     <tr>
#       <td id="T_2abf7_row9_col0" class="data row9 col0" >The Crew</td>
#       <td id="T_2abf7_row9_col1" class="data row9 col1" >7.767760</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Users rated

# %% [markdown]
# We can see how many users have rated the games.

# %%
sns.histplot(df['Users_rated'])
plt.title('Users rated')
plt.show()

# %% [markdown]
# Most of the games have not so many votes.

# %%
sns.histplot(df[df.Users_rated<5000]['Users_rated'])
plt.title('Users rated')
plt.show()

# %% [markdown]
# We can see the games with the most number of votes.

# %%
df[['Name','Users_rated']].sort_values('Users_rated',ascending=False)[:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2fbbd_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Users_rated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2fbbd_row0_col0" class="data row0 col0" >Pandemic</td>
#       <td id="T_2fbbd_row0_col1" class="data row0 col1" >110936</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row1_col0" class="data row1 col0" >Carcassonne</td>
#       <td id="T_2fbbd_row1_col1" class="data row1 col1" >110751</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row2_col0" class="data row2 col0" >7 Wonders</td>
#       <td id="T_2fbbd_row2_col1" class="data row2 col1" >91715</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row3_col0" class="data row3 col0" >7 Wonders Duel</td>
#       <td id="T_2fbbd_row3_col1" class="data row3 col1" >72375</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row4_col0" class="data row4 col0" >Splendor</td>
#       <td id="T_2fbbd_row4_col1" class="data row4 col1" >66481</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row5_col0" class="data row5 col0" >Puerto Rico</td>
#       <td id="T_2fbbd_row5_col1" class="data row5 col1" >66108</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row6_col0" class="data row6 col0" >Azul</td>
#       <td id="T_2fbbd_row6_col1" class="data row6 col1" >65896</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row7_col0" class="data row7 col0" >King of Tokyo</td>
#       <td id="T_2fbbd_row7_col1" class="data row7 col1" >62397</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row8_col0" class="data row8 col0" >Love Letter</td>
#       <td id="T_2fbbd_row8_col1" class="data row8 col1" >60492</td>
#     </tr>
#     <tr>
#       <td id="T_2fbbd_row9_col0" class="data row9 col0" >Patchwork</td>
#       <td id="T_2fbbd_row9_col1" class="data row9 col1" >53973</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And the ones with the least number of votes.

# %%
df[['Name','Users_rated']].sort_values('Users_rated')[:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d7c9_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Users_rated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d7c9_row0_col0" class="data row0 col0" >Medo</td>
#       <td id="T_2d7c9_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row1_col0" class="data row1 col0" >Alveole</td>
#       <td id="T_2d7c9_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row2_col0" class="data row2 col0" >Sparts</td>
#       <td id="T_2d7c9_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row3_col0" class="data row3 col0" >Icebreaker</td>
#       <td id="T_2d7c9_row3_col1" class="data row3 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row4_col0" class="data row4 col0" >Solo Whist</td>
#       <td id="T_2d7c9_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row5_col0" class="data row5 col0" >KQJ</td>
#       <td id="T_2d7c9_row5_col1" class="data row5 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row6_col0" class="data row6 col0" >Factum</td>
#       <td id="T_2d7c9_row6_col1" class="data row6 col1" >21</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row7_col0" class="data row7 col0" >Yin Yang</td>
#       <td id="T_2d7c9_row7_col1" class="data row7 col1" >21</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row8_col0" class="data row8 col0" >Detective Poker</td>
#       <td id="T_2d7c9_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_2d7c9_row9_col0" class="data row9 col0" >Lady's Choice</td>
#       <td id="T_2d7c9_row9_col1" class="data row9 col1" >25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Playing time

# %% [markdown]
# Let's see the playing time of the games. The playing time is in minutes.

# %%
sns.histplot(df['Playing_time'],kde=True)
plt.title('Playing time')
plt.show()

# %% [markdown]
# There is a game with a very long playing time. Let's see the ones with the longest playing time.

# %%
df[['Name','Playing_time']].sort_values('Playing_time',ascending=False)[:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_73fa0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Playing_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_73fa0_row0_col0" class="data row0 col0" >Unconditional Surrender! World War 2 in Europe</td>
#       <td id="T_73fa0_row0_col1" class="data row0 col1" >3000</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row1_col0" class="data row1 col0" >Tumbleweed</td>
#       <td id="T_73fa0_row1_col1" class="data row1 col1" >200</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row2_col0" class="data row2 col0" >Barbu</td>
#       <td id="T_73fa0_row2_col1" class="data row2 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row3_col0" class="data row3 col0" >Space Empires: 4X</td>
#       <td id="T_73fa0_row3_col1" class="data row3 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row4_col0" class="data row4 col0" >Carnegie</td>
#       <td id="T_73fa0_row4_col1" class="data row4 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row5_col0" class="data row5 col0" >ONE</td>
#       <td id="T_73fa0_row5_col1" class="data row5 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row6_col0" class="data row6 col0" >Go</td>
#       <td id="T_73fa0_row6_col1" class="data row6 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row7_col0" class="data row7 col0" >City of the Big Shoulders</td>
#       <td id="T_73fa0_row7_col1" class="data row7 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row8_col0" class="data row8 col0" >Gaia Project</td>
#       <td id="T_73fa0_row8_col1" class="data row8 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_73fa0_row9_col0" class="data row9 col0" >Caylus</td>
#       <td id="T_73fa0_row9_col1" class="data row9 col1" >150</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check if there are more games that last 150 minutes.

# %%
df[df.Playing_time>=150][['Name','Playing_time']].sort_values('Playing_time',ascending=False).style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a46a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Playing_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9a46a_row0_col0" class="data row0 col0" >Unconditional Surrender! World War 2 in Europe</td>
#       <td id="T_9a46a_row0_col1" class="data row0 col1" >3000</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row1_col0" class="data row1 col0" >Tumbleweed</td>
#       <td id="T_9a46a_row1_col1" class="data row1 col1" >200</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row2_col0" class="data row2 col0" >Carnegie</td>
#       <td id="T_9a46a_row2_col1" class="data row2 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row3_col0" class="data row3 col0" >City of the Big Shoulders</td>
#       <td id="T_9a46a_row3_col1" class="data row3 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row4_col0" class="data row4 col0" >Space Empires: 4X</td>
#       <td id="T_9a46a_row4_col1" class="data row4 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row5_col0" class="data row5 col0" >Barbu</td>
#       <td id="T_9a46a_row5_col1" class="data row5 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row6_col0" class="data row6 col0" >Go</td>
#       <td id="T_9a46a_row6_col1" class="data row6 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row7_col0" class="data row7 col0" >ONE</td>
#       <td id="T_9a46a_row7_col1" class="data row7 col1" >180</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row8_col0" class="data row8 col0" >Terra Mystica</td>
#       <td id="T_9a46a_row8_col1" class="data row8 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row9_col0" class="data row9 col0" >Gaia Project</td>
#       <td id="T_9a46a_row9_col1" class="data row9 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row10_col0" class="data row10 col0" >Puerto Rico</td>
#       <td id="T_9a46a_row10_col1" class="data row10 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row11_col0" class="data row11 col0" >Caylus</td>
#       <td id="T_9a46a_row11_col1" class="data row11 col1" >150</td>
#     </tr>
#     <tr>
#       <td id="T_9a46a_row12_col0" class="data row12 col0" >Madeira</td>
#       <td id="T_9a46a_row12_col1" class="data row12 col1" >150</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's plot the playing time without the game of 3000 minutes duration for a better description.

# %%
sns.histplot(df[df['Playing_time']<3000].Playing_time,kde=True)
plt.title('Playing time')
plt.show()

# %% [markdown]
# Now, let's see the games with the shortest playing time.

# %%
df[['Name','Playing_time']].sort_values('Playing_time')[:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a21c6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Playing_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a21c6_row0_col0" class="data row0 col0" >Chess</td>
#       <td id="T_a21c6_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row1_col0" class="data row1 col0" >Dodo</td>
#       <td id="T_a21c6_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row2_col0" class="data row2 col0" >KQJ</td>
#       <td id="T_a21c6_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row3_col0" class="data row3 col0" >Sparts</td>
#       <td id="T_a21c6_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row4_col0" class="data row4 col0" >Mammalath</td>
#       <td id="T_a21c6_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row5_col0" class="data row5 col0" >Gopher</td>
#       <td id="T_a21c6_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row6_col0" class="data row6 col0" >Insert</td>
#       <td id="T_a21c6_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row7_col0" class="data row7 col0" >Zola</td>
#       <td id="T_a21c6_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row8_col0" class="data row8 col0" >Gomoku</td>
#       <td id="T_a21c6_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_a21c6_row9_col0" class="data row9 col0" >Castles of Caleira</td>
#       <td id="T_a21c6_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Some games have 0 in playing time, which is wrong. The current playing time is missing. Let's see the games with no 0 playing time.

# %%
df[df.Playing_time!=0][['Name','Playing_time']].sort_values('Playing_time')[:10].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6b97_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Playing_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a6b97_row0_col0" class="data row0 col0" >Gomoku</td>
#       <td id="T_a6b97_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row1_col0" class="data row1 col0" >Four Color Cards</td>
#       <td id="T_a6b97_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row2_col0" class="data row2 col0" >Neutreeko</td>
#       <td id="T_a6b97_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row3_col0" class="data row3 col0" >Soluna</td>
#       <td id="T_a6b97_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row4_col0" class="data row4 col0" >Castles of Caleira</td>
#       <td id="T_a6b97_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row5_col0" class="data row5 col0" >Cinco</td>
#       <td id="T_a6b97_row5_col1" class="data row5 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row6_col0" class="data row6 col0" >Mijnlieff</td>
#       <td id="T_a6b97_row6_col1" class="data row6 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row7_col0" class="data row7 col0" >Linkage</td>
#       <td id="T_a6b97_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row8_col0" class="data row8 col0" >Balloon Pop!</td>
#       <td id="T_a6b97_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_a6b97_row9_col0" class="data row9 col0" >ToeShamBo</td>
#       <td id="T_a6b97_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check how many are with 10 minutes playing time or less.

# %%
df[(df.Playing_time!=0) & (df.Playing_time<=10)][['Name','Playing_time']].sort_values('Playing_time').style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f312_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Playing_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9f312_row0_col0" class="data row0 col0" >Gomoku</td>
#       <td id="T_9f312_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row1_col0" class="data row1 col0" >Martian Dice</td>
#       <td id="T_9f312_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row2_col0" class="data row2 col0" >Connect Four</td>
#       <td id="T_9f312_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row3_col0" class="data row3 col0" >Kalah</td>
#       <td id="T_9f312_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row4_col0" class="data row4 col0" >Secret Moon</td>
#       <td id="T_9f312_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row5_col0" class="data row5 col0" >Cinco</td>
#       <td id="T_9f312_row5_col1" class="data row5 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row6_col0" class="data row6 col0" >Pylos</td>
#       <td id="T_9f312_row6_col1" class="data row6 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row7_col0" class="data row7 col0" >Balloon Pop!</td>
#       <td id="T_9f312_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row8_col0" class="data row8 col0" >Neutreeko</td>
#       <td id="T_9f312_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row9_col0" class="data row9 col0" >ToeShamBo</td>
#       <td id="T_9f312_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row10_col0" class="data row10 col0" >Soluna</td>
#       <td id="T_9f312_row10_col1" class="data row10 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row11_col0" class="data row11 col0" >Castles of Caleira</td>
#       <td id="T_9f312_row11_col1" class="data row11 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row12_col0" class="data row12 col0" >Mijnlieff</td>
#       <td id="T_9f312_row12_col1" class="data row12 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row13_col0" class="data row13 col0" >Four Color Cards</td>
#       <td id="T_9f312_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9f312_row14_col0" class="data row14 col0" >Linkage</td>
#       <td id="T_9f312_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Number of players

# %%
sns.countplot(x="Max_players", data=df, order=df.sort_values('Max_players').Max_players.unique())
# Out:
# <AxesSubplot:xlabel='Max_players', ylabel='count'>

# %% [markdown]
# Most of the games has 4 as the maximum number of players.

# %%
sns.countplot(x="Min_players", data=df, order=df.sort_values('Min_players').Min_players.unique())
# Out:
# <AxesSubplot:xlabel='Min_players', ylabel='count'>

# %% [markdown]
# In the mayority of the games, 2 is the minumum number the players required.

# %% [markdown]
# You can play in solitary mode the following number of games:

# %%
df[df.Min_players==1].shape[0]
# Out:
# 57

# %% [markdown]
# Let's see how many games have a fixed number of players.

# %%
df[(df.Min_players==df.Max_players)].value_counts('Min_players')
# Out:
# Min_players
# 2    90
# 4     6
# 3     1
# dtype: int64

# %% [markdown]
# Number of 2 player games:

# %%
df[(df.Min_players==2)&(df.Min_players==df.Max_players)].shape[0]
# Out:
# 90

# %% [markdown]
# ### Designer - Artist

# %% [markdown]
# Which designers have the most games on BGA? Let's see the designers that have 3 or more games.

# %%
v = df.Designer.value_counts()
df[df.Designer.isin(v.index[v.gt(2)])].Designer.value_counts()
# Out:
# ['(Uncredited)']                                           39
# []                                                          9
# ['Sid Sackson']                                             5
# ['Antoine Bauza']                                           5
# ['Nick Bentley']                                            4
# ['Michael Schacht']                                         4
# ['Vlaada Chvátil']                                          4
# ['Phil Walker-Harding']                                     4
# ['Scott Almes']                                             4
# ['Stefan Dorra']                                            4
# ['Uwe Rosenberg']                                           3
# ['Frédéric Henry']                                          3
# ['József Dorsonczky']                                       3
# ['Ben Pinchback', 'Matt Riddle']                            3
# ['Sébastien Dujardin', 'Xavier Georges', 'Alain Orban']     3
# ['Simone Luciani', 'Daniele Tascini']                       3
# ['Andrew Looney']                                           3
# ['Cédrick Chaboussit']                                      3
# ['Régis Bonnessée']                                         3
# ['Thomas Lehmann']                                          3
# ['Bruno Cathala']                                           3
# ['Mark Steere']                                             3
# Name: Designer, dtype: int64

# %% [markdown]
# Most of the games does not have a designer/the designer is missing. The most popular designers in BGA are Antoine Bauza and Sid Sackson.

# %% [markdown]
# Let's see the artists.

# %%
w = df.Artist.value_counts()
df[df.Artist.isin(w.index[w.gt(2)])].Artist.value_counts()
# Out:
# []                                      83
# ['Dennis Lohausen']                      7
# ['(Uncredited)']                         6
# ['Néstor Romeral Andrés']                5
# ['Alexandre Roche']                      4
# ['Anne Heidsieck']                       3
# ['Michael Menzel']                       3
# ['Franz Vohwinkel']                      3
# ['Martin Hoffmann', 'Claus Stephan']     3
# ['Xavier Gueniffey Durin']               3
# ['Mariano Iannelli']                     3
# ['Kerri Aitken']                         3
# ['Arnaud Demaegd']                       3
# Name: Artist, dtype: int64

# %% [markdown]
# Most of the games does not have an artist/the artist is missing. The most popular artist in BGA is Dennis Lohausen.

# %% [markdown]
# ### Average weight

# %% [markdown]
# In BGG you have a [weight metric](https://boardgamegeek.com/wiki/page/Weight), which means how complex/difficult is the game. Lower rating (lighter weight) means easier.
# BGG uses a 5-point Weight scale:
#
# 1 Light
# 2 Medium Light
# 3 Medium
# 4 Medium Heavy
# 5 Heavy
#
# Each user can vote how heavy is a game, and then BGG computes the average weight of the game.

# %% [markdown]
# Let's plot a histogram of the Average weight.

# %%
sns.histplot(df['Average_weight'],kde=True)
plt.title('Average_weight')
plt.show()

# %% [markdown]
# Some games does not have an average weight yet. Let's plot the histogram without these games.

# %%
sns.histplot(df[df.Average_weight>0]['Average_weight'],kde=True)
plt.title('Average_weight')
plt.show()

# %% [markdown]
# The mayority of games in BGA are not so complex.

# %% [markdown]
# ### Correlation between variables

# %% [markdown]
# Let's see if there is correlation between the numeric columns. We consider only games with Bayes_average_rating and Average_weight greater than 0.

# %%
data=df[(df.Average_weight>0) & (df.Bayes_average_rating>0)]
data=data[['Year', 'Min_players', 'Max_players', 'Playing_time',
       'Average_rating', 'Users_rated', 'Bayes_average_rating',
       'Average_weight']]
trimask = np.tri(data.corr().shape[0],data.corr().shape[0], dtype=bool)
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), 
            mask=~trimask ,
            annot=True,
            cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see that there is a correlation between the two types of rating, the number of users that rate the game with the bayes average rating, and a moderate correlation between the average weight and the average rating. Let's see that in detail:

# %%
sns.lmplot(data=df[(df.Average_weight>0)],
    x="Average_rating", y="Average_weight", line_kws={'color': 'g'})

# %% [markdown]
# ### Category columns

# %% [markdown]
# Let's explore now the category columns.

# %%
#category columns
category_cols = [col for col in df.columns if 'Category:' in col]

# %%
category_cols_2=[col.replace('Category: ', '') for col in category_cols]

# %%
print('We have ' + str(len(category_cols)) + ' categories.' )
# Out:
# We have 67 categories.

# %% [markdown]
# We have the following game categories:

# %%
sorted(category_cols_2)
# Out:
# ['Abstract Strategy',
#  'Adventure',
#  'Age of Reason',
#  'American West',
#  'Ancient',
#  'Animals',
#  'Arabian',
#  'Aviation / Flight',
#  'Bluffing',
#  'Card Game',
#  "Children's Game",
#  'City Building',
#  'Civilization',
#  'Collectible Components',
#  'Comic Book / Strip',
#  'Deduction',
#  'Dice',
#  'Economic',
#  'Educational',
#  'Environmental',
#  'Exploration',
#  'Fantasy',
#  'Farming',
#  'Fighting',
#  'Game System',
#  'Horror',
#  'Humor',
#  'Industry / Manufacturing',
#  'Mafia',
#  'Math',
#  'Maze',
#  'Medical',
#  'Medieval',
#  'Memory',
#  'Miniatures',
#  'Movies / TV / Radio theme',
#  'Murder/Mystery',
#  'Music',
#  'Mythology',
#  'Nautical',
#  'Negotiation',
#  'Novel-based',
#  'Number',
#  'Party Game',
#  'Pirates',
#  'Political',
#  'Post-Napoleonic',
#  'Prehistoric',
#  'Print & Play',
#  'Puzzle',
#  'Racing',
#  'Real-time',
#  'Religious',
#  'Renaissance',
#  'Science Fiction',
#  'Space Exploration',
#  'Spies/Secret Agents',
#  'Sports',
#  'Territory Building',
#  'Trains',
#  'Transportation',
#  'Travel',
#  'Video Game Theme',
#  'Wargame',
#  'Word Game',
#  'World War II',
#  'Zombies']

# %% [markdown]
# The category ['Print & Play'](https://boardgamegeek.com/boardgamecategory/1120/print-play) is not a category that tell us what the game is about, so we will remove it from our data frame.

# %%
df=df.drop(['Category: Print & Play'], axis=1)

# %% [markdown]
# We count the number of games that belong to each category.

# %%
category_cols = [col for col in df.columns if 'Category:' in col]
category_list=df[category_cols].sum().sort_values(ascending=False).index.tolist()
category_list2=[category.replace('Category: ','') for category in category_list]
category_count=df[category_cols].sum().sort_values(ascending=False)[0:].tolist()

# %%
sns.set(rc = {'figure.figsize':(15,20)})
sns.barplot(y=category_list2,x=category_count)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The most popular categories are:

# %%
df[category_cols].replace('Category: ', '').sum().sort_values(ascending=False)[0:10].rename(index=dict(zip(category_list, category_list2)))
# Out:
# Card Game            165.0
# Abstract Strategy    106.0
# Economic              51.0
# Fantasy               44.0
# Dice                  37.0
# Deduction             34.0
# Animals               27.0
# Science Fiction       27.0
# Bluffing              26.0
# Medieval              25.0
# dtype: float64

# %%
popular_categories=df[category_cols].sum().sort_values(ascending=False).index[0:10]

# %% [markdown]
# Let's analyze the average weight, the average rating and the bayes average rating of the games by category:

# %%
results = []
for category in popular_categories:
    results.append(df[(df[category]==1.0) & (df['Average_weight']>0)].Average_weight)
# boxplot algorithm comparison
fig = plt.figure(figsize=(16, 6))
ax = sns.boxplot(data=results)
ax.set_title('Average weight by category')
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace(' ', '\n') for label in category_list2[0:10]])
plt.show()

# %% [markdown]
# We can see that the economic games are in average, more complex than games in other categories.

# %%
results = []
for category in popular_categories:
    results.append(df[(df[category]==1.0)].Average_rating)
# boxplot algorithm comparison
fig = plt.figure(figsize=(16, 6))
ax = sns.boxplot(data=results)
ax.set_title('Average rating by category')
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace(' ', '\n') for label in category_list2[0:10]])
plt.show()

# %%
results = []
for category in popular_categories:
    results.append(df[(df[category]==1.0) & (df['Bayes_average_rating']>0)].Bayes_average_rating)
# boxplot algorithm comparison
fig = plt.figure(figsize=(16, 6))
ax = sns.boxplot(data=results)
ax.set_title('Bayes average rating by category')
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace(' ', '\n') for label in category_list2[0:10]])
plt.show()

# %% [markdown]
# The economic games also have the highest ratings in average.

# %% [markdown]
# ### Mechanic columns

# %% [markdown]
# Let's explore the mechanic columns.

# %%
#Mechanic columns
mechanic_cols = [col for col in df.columns if 'Mechanic:' in col]   
mechanic_cols_2 = [col.replace('Mechanic: ', '') for col in mechanic_cols]

# %%
print('We have ' + str(len(mechanic_cols)) + ' mechanics.' )
# Out:
# We have 152 mechanics.

# %% [markdown]
# We have the following game mechanics:

# %%
sorted(mechanic_cols_2)
# Out:
# ['Acting',
#  'Action Drafting',
#  'Action Points',
#  'Action Queue',
#  'Action Retrieval',
#  'Action/Event',
#  'Advantage Token',
#  'Area Majority / Influence',
#  'Area Movement',
#  'Area-Impulse',
#  'Auction/Bidding',
#  'Auction: Dutch',
#  'Auction: Dutch Priority',
#  'Auction: Fixed Placement',
#  'Auction: Once Around',
#  'Auction: Sealed Bid',
#  'Auction: Turn Order Until Pass',
#  'Automatic Resource Growth',
#  'Betting and Bluffing',
#  'Bias',
#  'Bingo',
#  'Campaign / Battle Card Driven',
#  'Card Play Conflict Resolution',
#  'Catch the Leader',
#  'Chaining',
#  'Closed Drafting',
#  'Closed Economy Auction',
#  'Command Cards',
#  'Commodity Speculation',
#  'Communication Limits',
#  'Connections',
#  'Constrained Bidding',
#  'Contracts',
#  'Cooperative Game',
#  'Critical Hits and Failures',
#  'Deck Construction',
#  'Deck, Bag, and Pool Building',
#  'Deduction',
#  'Delayed Purchase',
#  'Dice Rolling',
#  'Die Icon Resolution',
#  'Different Dice Movement',
#  'Enclosure',
#  'End Game Bonuses',
#  'Events',
#  'Follow',
#  'Grid Coverage',
#  'Grid Movement',
#  'Hand Management',
#  'Hexagon Grid',
#  'Hidden Roles',
#  'Hidden Victory Points',
#  'Highest-Lowest Scoring',
#  'I Cut, You Choose',
#  'Income',
#  'Increase Value of Unchosen Resources',
#  'Investment',
#  'Kill Steal',
#  'King of the Hill',
#  'Ladder Climbing',
#  'Layering',
#  'Line Drawing',
#  'Line of Sight',
#  'Loans',
#  'Lose a Turn',
#  'Mancala',
#  'Map Addition',
#  'Map Deformation',
#  'Map Reduction',
#  'Market',
#  'Matching',
#  'Measurement Movement',
#  'Melding and Splaying',
#  'Memory',
#  'Modular Board',
#  'Move Through Deck',
#  'Movement Points',
#  'Movement Template',
#  'Moving Multiple Units',
#  'Multiple Maps',
#  'Multiple-Lot Auction',
#  'Narrative Choice / Paragraph',
#  'Negotiation',
#  'Network and Route Building',
#  'Once-Per-Game Abilities',
#  'Open Drafting',
#  'Ownership',
#  'Paper-and-Pencil',
#  'Pattern Building',
#  'Pattern Movement',
#  'Pattern Recognition',
#  'Pick-up and Deliver',
#  'Pieces as Map',
#  'Player Elimination',
#  'Player Judge',
#  'Point to Point Movement',
#  'Predictive Bid',
#  'Programmed Movement',
#  'Push Your Luck',
#  'Race',
#  'Random Production',
#  'Ratio / Combat Results Table',
#  'Re-rolling and Locking',
#  'Resource to Move',
#  'Rock-Paper-Scissors',
#  'Role Playing',
#  'Roll / Spin and Move',
#  'Rondel',
#  'Scenario / Mission / Campaign Game',
#  'Score-and-Reset Game',
#  'Secret Unit Deployment',
#  'Selection Order Bid',
#  'Set Collection',
#  'Simulation',
#  'Simultaneous Action Selection',
#  'Single Loser Game',
#  'Slide/Push',
#  'Solo / Solitaire Game',
#  'Speed Matching',
#  'Square Grid',
#  'Stacking and Balancing',
#  'Static Capture',
#  'Stock Holding',
#  'Storytelling',
#  'Sudden Death Ending',
#  'Take That',
#  'Targeted Clues',
#  'Team-Based Game',
#  'Tech Trees / Tech Tracks',
#  'Three Dimensional Movement',
#  'Tile Placement',
#  'Time Track',
#  'Track Movement',
#  'Trading',
#  'Traitor Game',
#  'Trick-taking',
#  'Tug of War',
#  'Turn Order: Auction',
#  'Turn Order: Claim Action',
#  'Turn Order: Pass Order',
#  'Turn Order: Progressive',
#  'Turn Order: Role Order',
#  'Turn Order: Stat-Based',
#  'Variable Phase Order',
#  'Variable Player Powers',
#  'Variable Set-up',
#  'Victory Points as a Resource',
#  'Voting',
#  'Worker Placement',
#  'Worker Placement with Dice Workers',
#  'Worker Placement, Different Worker Types',
#  'Zone of Control']

# %% [markdown]
# We count the number of games that belong to each category.

# %%
mechanic_list=df[mechanic_cols].sum().sort_values(ascending=False).index.tolist()
mechanic_list2=[mechanic.replace('Mechanic: ','') for mechanic in mechanic_list]
mechanic_count=df[mechanic_cols].sum().sort_values(ascending=False)[0:].tolist()

# %%
sns.set(rc = {'figure.figsize':(17,60)})
sns.barplot(y=mechanic_list2,x=mechanic_count)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The most popular mechanics are:

# %%
df[mechanic_cols].replace('Mechanic: ', '').sum().sort_values(ascending=False)[0:15].rename(index=dict(zip(mechanic_list, mechanic_list2)))
# Out:
# Hand Management              133.0
# Set Collection               111.0
# Open Drafting                 76.0
# Tile Placement                68.0
# Dice Rolling                  63.0
# Grid Movement                 47.0
# Area Majority / Influence     46.0
# Variable Player Powers        42.0
# Pattern Building              41.0
# Push Your Luck                37.0
# Trick-taking                  34.0
# Modular Board                 34.0
# Worker Placement              33.0
# Team-Based Game               33.0
# Solo / Solitaire Game         29.0
# dtype: float64

# %%
popular_mechanics=df[mechanic_cols].sum().sort_values(ascending=False).index[0:15]

# %% [markdown]
# Let's analyze the average weight, the average rating and the bayes average rating of the games by mechanic. As we have more mechanics, we consider the 15 most popular (instead of 10).

# %%
results = []
for mechanic in popular_mechanics:
    results.append(df[(df[mechanic]==1.0) & (df['Average_weight']>0)].Average_weight)
# boxplot algorithm comparison
fig = plt.figure(figsize=(21, 7))
ax = sns.boxplot(data=results)
ax.set_title('Average weight by mechanic',fontsize=14)
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace('-','- ').replace(' / ','- ').replace(' ', '\n') for label in mechanic_list2[0:15]],fontsize=12.5)
plt.show()

# %% [markdown]
# We can see that the games that belong to the mechanic "Worker Placement" have highest average weight than the others, and the mechanic "Push your luck" is the one with the lowest weight in average.

# %%
results = []
for mechanic in popular_mechanics:
    results.append(df[(df[mechanic]==1.0)].Average_rating)
# boxplot algorithm comparison
fig = plt.figure(figsize=(21, 7))
ax = sns.boxplot(data=results)
ax.set_title('Average rating by mechanic',fontsize=14)
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace('-','- ').replace(' / ','- ').replace(' ', '\n') for label in mechanic_list2[0:15]],fontsize=12.5)
plt.show()

# %%
results = []
for mechanic in popular_mechanics:
    results.append(df[(df[mechanic]==1.0) & (df['Bayes_average_rating']>0)].Bayes_average_rating)
# boxplot algorithm comparison
fig = plt.figure(figsize=(21, 7))
ax = sns.boxplot(data=results)
ax.set_title('Bayes average rating by mechanic',fontsize=14)
#ax.set_xticklabels(category_list2[0:10])
ax.set_xticklabels([label.replace('-','- ').replace(' / ','- ').replace(' ', '\n') for label in mechanic_list2[0:15]],fontsize=12.5)
plt.show()

# %% [markdown]
# The games with the worker placement mechanic have the highest ratings in average.

# %% [markdown]
# ### Combination of categories and mechanics

# %% [markdown]
# Let's see which combinations of category/mechanic are the most populars in BGA.

# %%
combination=[]
for cat in category_cols:
    for mec in mechanic_cols:
        combination.append((cat.replace('Category: ', '') + '/' + mec.replace('Mechanic: ', ''),df[(df[cat]==1.0) & (df[mec]==1.0)].shape[0]))

# %%
combination
# Out:
# [('Deduction/Action Points', 1),
#  ('Deduction/Hand Management', 11),
#  ('Deduction/Memory', 7),
#  ('Deduction/Kill Steal', 1),
#  ('Deduction/Score-and-Reset Game', 2),
#  ('Deduction/Simultaneous Action Selection', 4),
#  ('Deduction/Closed Drafting', 0),
#  ('Deduction/Set Collection', 5),
#  ('Deduction/Variable Player Powers', 7),
#  ('Deduction/Layering', 0),
#  ('Deduction/Open Drafting', 6),
#  ('Deduction/Sudden Death Ending', 0),
#  ('Deduction/Tug of War', 0),
#  ('Deduction/Action Queue', 1),
#  ('Deduction/Team-Based Game', 7),
#  ('Deduction/Grid Movement', 3),
#  ('Deduction/Hexagon Grid', 2),
#  ('Deduction/Slide/Push', 0),
#  ('Deduction/Static Capture', 0),
#  ('Deduction/Deck, Bag, and Pool Building', 2),
#  ('Deduction/Auction/Bidding', 2),
#  ('Deduction/Push Your Luck', 2),
#  ('Deduction/Enclosure', 0),
#  ('Deduction/Worker Placement', 0),
#  ('Deduction/Advantage Token', 0),
#  ('Deduction/Automatic Resource Growth', 0),
#  ('Deduction/Increase Value of Unchosen Resources', 0),
#  ('Deduction/Solo / Solitaire Game', 0),
#  ('Deduction/Turn Order: Claim Action', 0),
#  ('Deduction/Tile Placement', 3),
#  ('Deduction/Area Majority / Influence', 2),
#  ('Deduction/Secret Unit Deployment', 2),
#  ('Deduction/Race', 0),
#  ('Deduction/Betting and Bluffing', 0),
#  ('Deduction/Dice Rolling', 0),
#  ('Deduction/Roll / Spin and Move', 0),
#  ('Deduction/Track Movement', 0),
#  ('Deduction/Paper-and-Pencil', 1),
#  ('Deduction/Re-rolling and Locking', 0),
#  ('Deduction/Cooperative Game', 5),
#  ('Deduction/Network and Route Building', 0),
#  ('Deduction/Hidden Roles', 4),
#  ('Deduction/Player Elimination', 5),
#  ('Deduction/Take That', 2),
#  ('Deduction/Trick-taking', 1),
#  ('Deduction/Modular Board', 3),
#  ('Deduction/Action Drafting', 0),
#  ('Deduction/Contracts', 0),
#  ('Deduction/Events', 0),
#  ('Deduction/Point to Point Movement', 0),
#  ('Deduction/Tech Trees / Tech Tracks', 0),
#  ('Deduction/Auction: Once Around', 0),
#  ('Deduction/Simulation', 0),
#  ('Deduction/Matching', 0),
#  ('Deduction/Investment', 0),
#  ('Deduction/Pattern Movement', 0),
#  ('Deduction/Square Grid', 0),
#  ('Deduction/Pick-up and Deliver', 0),
#  ('Deduction/Pattern Building', 3),
#  ('Deduction/Loans', 0),
#  ('Deduction/Map Addition', 0),
#  ('Deduction/Action Retrieval', 0),
#  ('Deduction/Area Movement', 1),
#  ('Deduction/Connections', 0),
#  ('Deduction/End Game Bonuses', 0),
#  ('Deduction/Follow', 0),
#  ('Deduction/Income', 0),
#  ('Deduction/Movement Points', 0),
#  ('Deduction/Resource to Move', 0),
#  ('Deduction/Turn Order: Progressive', 0),
#  ('Deduction/Variable Phase Order', 0),
#  ('Deduction/Worker Placement, Different Worker Types', 0),
#  ('Deduction/Grid Coverage', 0),
#  ('Deduction/Turn Order: Stat-Based', 0),
#  ('Deduction/Variable Set-up', 0),
#  ('Deduction/Worker Placement with Dice Workers', 0),
#  ('Deduction/Ownership', 0),
#  ('Deduction/Turn Order: Pass Order', 0),
#  ('Deduction/Hidden Victory Points', 0),
#  ('Deduction/Commodity Speculation', 0),
#  ('Deduction/Stock Holding', 0),
#  ('Deduction/Market', 0),
#  ('Deduction/Programmed Movement', 1),
#  ('Deduction/Command Cards', 0),
#  ('Deduction/Communication Limits', 4),
#  ('Deduction/Scenario / Mission / Campaign Game', 0),
#  ('Deduction/Voting', 1),
#  ('Deduction/Deduction', 6),
#  ('Deduction/Trading', 0),
#  ('Deduction/Move Through Deck', 0),
#  ('Deduction/Random Production', 0),
#  ('Deduction/Pattern Recognition', 1),
#  ('Deduction/Bingo', 0),
#  ('Deduction/Moving Multiple Units', 0),
#  ('Deduction/Predictive Bid', 0),
#  ('Deduction/Map Deformation', 0),
#  ('Deduction/Rock-Paper-Scissors', 0),
#  ('Deduction/Victory Points as a Resource', 0),
#  ('Deduction/Auction: Sealed Bid', 0),
#  ('Deduction/Auction: Turn Order Until Pass', 0),
#  ('Deduction/Selection Order Bid', 0),
#  ('Deduction/Map Reduction', 0),
#  ('Deduction/Mancala', 0),
#  ('Deduction/Catch the Leader', 0),
#  ('Deduction/Ladder Climbing', 0),
#  ('Deduction/Delayed Purchase', 0),
#  ('Deduction/Pieces as Map', 0),
#  ('Deduction/Three Dimensional Movement', 0),
#  ('Deduction/Auction: Fixed Placement', 0),
#  ('Deduction/Constrained Bidding', 0),
#  ('Deduction/Melding and Splaying', 0),
#  ('Deduction/Multiple-Lot Auction', 0),
#  ('Deduction/Turn Order: Auction', 0),
#  ('Deduction/Multiple Maps', 0),
#  ('Deduction/Chaining', 0),
#  ('Deduction/Critical Hits and Failures', 0),
#  ('Deduction/Line of Sight', 0),
#  ('Deduction/Zone of Control', 0),
#  ('Deduction/Turn Order: Role Order', 0),
#  ('Deduction/Area-Impulse', 0),
#  ('Deduction/Once-Per-Game Abilities', 0),
#  ('Deduction/Bias', 0),
#  ('Deduction/Closed Economy Auction', 0),
#  ('Deduction/Single Loser Game', 0),
#  ('Deduction/Time Track', 0),
#  ('Deduction/I Cut, You Choose', 0),
#  ('Deduction/Line Drawing', 0),
#  ('Deduction/Different Dice Movement', 0),
#  ('Deduction/Acting', 0),
#  ('Deduction/Storytelling', 1),
#  ('Deduction/Traitor Game', 1),
#  ('Deduction/Auction: Dutch', 0),
#  ('Deduction/Lose a Turn', 0),
#  ('Deduction/Auction: Dutch Priority', 0),
#  ('Deduction/Deck Construction', 0),
#  ('Deduction/Highest-Lowest Scoring', 0),
#  ('Deduction/Rondel', 0),
#  ('Deduction/Campaign / Battle Card Driven', 0),
#  ('Deduction/Ratio / Combat Results Table', 0),
#  ('Deduction/Role Playing', 1),
#  ('Deduction/Negotiation', 0),
#  ('Deduction/Player Judge', 0),
#  ('Deduction/Die Icon Resolution', 0),
#  ('Deduction/King of the Hill', 0),
#  ('Deduction/Action/Event', 0),
#  ('Deduction/Targeted Clues', 0),
#  ('Deduction/Stacking and Balancing', 0),
#  ('Deduction/Card Play Conflict Resolution', 0),
#  ('Deduction/Speed Matching', 0),
#  ('Deduction/Narrative Choice / Paragraph', 1),
#  ('Deduction/Measurement Movement', 0),
#  ('Deduction/Movement Template', 0),
#  ('Memory/Action Points', 1),
#  ('Memory/Hand Management', 4),
#  ('Memory/Memory', 6),
#  ('Memory/Kill Steal', 0),
#  ('Memory/Score-and-Reset Game', 0),
#  ('Memory/Simultaneous Action Selection', 0),
#  ('Memory/Closed Drafting', 0),
#  ('Memory/Set Collection', 3),
#  ('Memory/Variable Player Powers', 0),
#  ('Memory/Layering', 0),
#  ('Memory/Open Drafting', 0),
#  ('Memory/Sudden Death Ending', 0),
#  ('Memory/Tug of War', 0),
#  ('Memory/Action Queue', 0),
#  ('Memory/Team-Based Game', 1),
#  ('Memory/Grid Movement', 1),
#  ('Memory/Hexagon Grid', 0),
#  ('Memory/Slide/Push', 0),
#  ('Memory/Static Capture', 0),
#  ('Memory/Deck, Bag, and Pool Building', 0),
#  ('Memory/Auction/Bidding', 0),
#  ('Memory/Push Your Luck', 1),
#  ('Memory/Enclosure', 0),
#  ('Memory/Worker Placement', 0),
#  ('Memory/Advantage Token', 0),
#  ('Memory/Automatic Resource Growth', 0),
#  ('Memory/Increase Value of Unchosen Resources', 0),
#  ('Memory/Solo / Solitaire Game', 0),
#  ('Memory/Turn Order: Claim Action', 0),
#  ('Memory/Tile Placement', 0),
#  ('Memory/Area Majority / Influence', 0),
#  ('Memory/Secret Unit Deployment', 0),
#  ('Memory/Race', 0),
#  ('Memory/Betting and Bluffing', 0),
#  ('Memory/Dice Rolling', 0),
#  ('Memory/Roll / Spin and Move', 0),
#  ('Memory/Track Movement', 0),
#  ('Memory/Paper-and-Pencil', 0),
#  ('Memory/Re-rolling and Locking', 0),
#  ('Memory/Cooperative Game', 2),
#  ('Memory/Network and Route Building', 0),
#  ('Memory/Hidden Roles', 0),
#  ('Memory/Player Elimination', 0),
#  ('Memory/Take That', 0),
#  ('Memory/Trick-taking', 0),
#  ('Memory/Modular Board', 0),
#  ('Memory/Action Drafting', 0),
#  ('Memory/Contracts', 0),
#  ('Memory/Events', 0),
#  ('Memory/Point to Point Movement', 0),
#  ('Memory/Tech Trees / Tech Tracks', 0),
#  ('Memory/Auction: Once Around', 0),
#  ('Memory/Simulation', 0),
#  ('Memory/Matching', 0),
#  ('Memory/Investment', 0),
#  ('Memory/Pattern Movement', 0),
#  ('Memory/Square Grid', 0),
#  ('Memory/Pick-up and Deliver', 0),
#  ('Memory/Pattern Building', 2),
#  ('Memory/Loans', 0),
#  ('Memory/Map Addition', 0),
#  ('Memory/Action Retrieval', 0),
#  ('Memory/Area Movement', 0),
#  ('Memory/Connections', 0),
#  ('Memory/End Game Bonuses', 0),
#  ('Memory/Follow', 0),
#  ('Memory/Income', 0),
#  ('Memory/Movement Points', 0),
#  ('Memory/Resource to Move', 0),
#  ('Memory/Turn Order: Progressive', 0),
#  ('Memory/Variable Phase Order', 0),
#  ('Memory/Worker Placement, Different Worker Types', 0),
#  ('Memory/Grid Coverage', 0),
#  ('Memory/Turn Order: Stat-Based', 0),
#  ('Memory/Variable Set-up', 0),
#  ('Memory/Worker Placement with Dice Workers', 0),
#  ('Memory/Ownership', 0),
#  ('Memory/Turn Order: Pass Order', 0),
#  ('Memory/Hidden Victory Points', 0),
#  ('Memory/Commodity Speculation', 0),
#  ('Memory/Stock Holding', 0),
#  ('Memory/Market', 0),
#  ('Memory/Programmed Movement', 0),
#  ('Memory/Command Cards', 0),
#  ('Memory/Communication Limits', 2),
#  ('Memory/Scenario / Mission / Campaign Game', 0),
#  ('Memory/Voting', 0),
#  ('Memory/Deduction', 0),
#  ('Memory/Trading', 1),
#  ('Memory/Move Through Deck', 0),
#  ('Memory/Random Production', 0),
#  ('Memory/Pattern Recognition', 1),
#  ('Memory/Bingo', 0),
#  ('Memory/Moving Multiple Units', 0),
#  ('Memory/Predictive Bid', 0),
#  ('Memory/Map Deformation', 0),
#  ('Memory/Rock-Paper-Scissors', 0),
#  ('Memory/Victory Points as a Resource', 0),
#  ('Memory/Auction: Sealed Bid', 0),
#  ('Memory/Auction: Turn Order Until Pass', 0),
#  ('Memory/Selection Order Bid', 0),
#  ('Memory/Map Reduction', 0),
#  ('Memory/Mancala', 0),
#  ('Memory/Catch the Leader', 0),
#  ('Memory/Ladder Climbing', 0),
#  ('Memory/Delayed Purchase', 0),
#  ('Memory/Pieces as Map', 0),
#  ('Memory/Three Dimensional Movement', 0),
#  ('Memory/Auction: Fixed Placement', 0),
#  ('Memory/Constrained Bidding', 0),
#  ('Memory/Melding and Splaying', 0),
#  ('Memory/Multiple-Lot Auction', 0),
#  ('Memory/Turn Order: Auction', 0),
#  ('Memory/Multiple Maps', 0),
#  ('Memory/Chaining', 0),
#  ('Memory/Critical Hits and Failures', 0),
#  ('Memory/Line of Sight', 0),
#  ('Memory/Zone of Control', 0),
#  ('Memory/Turn Order: Role Order', 0),
#  ('Memory/Area-Impulse', 0),
#  ('Memory/Once-Per-Game Abilities', 0),
#  ('Memory/Bias', 0),
#  ('Memory/Closed Economy Auction', 0),
#  ('Memory/Single Loser Game', 0),
#  ('Memory/Time Track', 0),
#  ('Memory/I Cut, You Choose', 0),
#  ('Memory/Line Drawing', 0),
#  ('Memory/Different Dice Movement', 0),
#  ('Memory/Acting', 0),
#  ('Memory/Storytelling', 0),
#  ('Memory/Traitor Game', 0),
#  ('Memory/Auction: Dutch', 0),
#  ('Memory/Lose a Turn', 0),
#  ('Memory/Auction: Dutch Priority', 0),
#  ('Memory/Deck Construction', 0),
#  ('Memory/Highest-Lowest Scoring', 0),
#  ('Memory/Rondel', 0),
#  ('Memory/Campaign / Battle Card Driven', 0),
#  ('Memory/Ratio / Combat Results Table', 0),
#  ('Memory/Role Playing', 0),
#  ('Memory/Negotiation', 0),
#  ('Memory/Player Judge', 0),
#  ('Memory/Die Icon Resolution', 0),
#  ('Memory/King of the Hill', 0),
#  ('Memory/Action/Event', 0),
#  ('Memory/Targeted Clues', 0),
#  ('Memory/Stacking and Balancing', 0),
#  ('Memory/Card Play Conflict Resolution', 0),
#  ('Memory/Speed Matching', 0),
#  ('Memory/Narrative Choice / Paragraph', 0),
#  ('Memory/Measurement Movement', 0),
#  ('Memory/Movement Template', 0),
#  ('Murder/Mystery/Action Points', 1),
#  ('Murder/Mystery/Hand Management', 1),
#  ('Murder/Mystery/Memory', 1),
#  ('Murder/Mystery/Kill Steal', 0),
#  ('Murder/Mystery/Score-and-Reset Game', 0),
#  ('Murder/Mystery/Simultaneous Action Selection', 0),
#  ('Murder/Mystery/Closed Drafting', 0),
#  ('Murder/Mystery/Set Collection', 0),
#  ('Murder/Mystery/Variable Player Powers', 3),
#  ('Murder/Mystery/Layering', 0),
#  ('Murder/Mystery/Open Drafting', 2),
#  ('Murder/Mystery/Sudden Death Ending', 0),
#  ('Murder/Mystery/Tug of War', 0),
#  ('Murder/Mystery/Action Queue', 0),
#  ('Murder/Mystery/Team-Based Game', 1),
#  ('Murder/Mystery/Grid Movement', 1),
#  ('Murder/Mystery/Hexagon Grid', 1),
#  ('Murder/Mystery/Slide/Push', 0),
#  ('Murder/Mystery/Static Capture', 0),
#  ('Murder/Mystery/Deck, Bag, and Pool Building', 0),
#  ('Murder/Mystery/Auction/Bidding', 0),
#  ('Murder/Mystery/Push Your Luck', 0),
#  ('Murder/Mystery/Enclosure', 0),
#  ('Murder/Mystery/Worker Placement', 0),
#  ('Murder/Mystery/Advantage Token', 0),
#  ('Murder/Mystery/Automatic Resource Growth', 0),
#  ('Murder/Mystery/Increase Value of Unchosen Resources', 0),
#  ('Murder/Mystery/Solo / Solitaire Game', 0),
#  ('Murder/Mystery/Turn Order: Claim Action', 0),
#  ('Murder/Mystery/Tile Placement', 1),
#  ('Murder/Mystery/Area Majority / Influence', 0),
#  ('Murder/Mystery/Secret Unit Deployment', 1),
#  ('Murder/Mystery/Race', 0),
#  ('Murder/Mystery/Betting and Bluffing', 0),
#  ('Murder/Mystery/Dice Rolling', 0),
#  ('Murder/Mystery/Roll / Spin and Move', 0),
#  ('Murder/Mystery/Track Movement', 0),
#  ('Murder/Mystery/Paper-and-Pencil', 0),
#  ('Murder/Mystery/Re-rolling and Locking', 0),
#  ('Murder/Mystery/Cooperative Game', 1),
#  ('Murder/Mystery/Network and Route Building', 0),
#  ('Murder/Mystery/Hidden Roles', 1),
#  ('Murder/Mystery/Player Elimination', 1),
#  ('Murder/Mystery/Take That', 0),
#  ('Murder/Mystery/Trick-taking', 0),
#  ('Murder/Mystery/Modular Board', 1),
#  ('Murder/Mystery/Action Drafting', 0),
#  ('Murder/Mystery/Contracts', 0),
#  ('Murder/Mystery/Events', 0),
#  ('Murder/Mystery/Point to Point Movement', 0),
#  ('Murder/Mystery/Tech Trees / Tech Tracks', 0),
#  ('Murder/Mystery/Auction: Once Around', 0),
#  ('Murder/Mystery/Simulation', 0),
#  ('Murder/Mystery/Matching', 0),
#  ('Murder/Mystery/Investment', 0),
#  ('Murder/Mystery/Pattern Movement', 0),
#  ('Murder/Mystery/Square Grid', 0),
#  ('Murder/Mystery/Pick-up and Deliver', 0),
#  ('Murder/Mystery/Pattern Building', 0),
#  ('Murder/Mystery/Loans', 0),
#  ('Murder/Mystery/Map Addition', 0),
#  ('Murder/Mystery/Action Retrieval', 0),
#  ('Murder/Mystery/Area Movement', 0),
#  ('Murder/Mystery/Connections', 0),
#  ('Murder/Mystery/End Game Bonuses', 0),
#  ('Murder/Mystery/Follow', 0),
#  ('Murder/Mystery/Income', 0),
#  ('Murder/Mystery/Movement Points', 0),
#  ('Murder/Mystery/Resource to Move', 0),
#  ('Murder/Mystery/Turn Order: Progressive', 0),
#  ('Murder/Mystery/Variable Phase Order', 0),
#  ('Murder/Mystery/Worker Placement, Different Worker Types', 0),
#  ('Murder/Mystery/Grid Coverage', 0),
#  ('Murder/Mystery/Turn Order: Stat-Based', 0),
#  ('Murder/Mystery/Variable Set-up', 0),
#  ('Murder/Mystery/Worker Placement with Dice Workers', 0),
#  ('Murder/Mystery/Ownership', 0),
#  ('Murder/Mystery/Turn Order: Pass Order', 0),
#  ('Murder/Mystery/Hidden Victory Points', 0),
#  ('Murder/Mystery/Commodity Speculation', 0),
#  ('Murder/Mystery/Stock Holding', 0),
#  ('Murder/Mystery/Market', 0),
#  ('Murder/Mystery/Programmed Movement', 0),
#  ('Murder/Mystery/Command Cards', 0),
#  ('Murder/Mystery/Communication Limits', 0),
#  ('Murder/Mystery/Scenario / Mission / Campaign Game', 0),
#  ('Murder/Mystery/Voting', 1),
#  ('Murder/Mystery/Deduction', 2),
#  ('Murder/Mystery/Trading', 0),
#  ('Murder/Mystery/Move Through Deck', 0),
#  ('Murder/Mystery/Random Production', 0),
#  ('Murder/Mystery/Pattern Recognition', 0),
#  ('Murder/Mystery/Bingo', 0),
#  ('Murder/Mystery/Moving Multiple Units', 0),
#  ('Murder/Mystery/Predictive Bid', 0),
#  ('Murder/Mystery/Map Deformation', 0),
#  ('Murder/Mystery/Rock-Paper-Scissors', 0),
#  ('Murder/Mystery/Victory Points as a Resource', 0),
#  ('Murder/Mystery/Auction: Sealed Bid', 0),
#  ('Murder/Mystery/Auction: Turn Order Until Pass', 0),
#  ('Murder/Mystery/Selection Order Bid', 0),
#  ('Murder/Mystery/Map Reduction', 0),
#  ('Murder/Mystery/Mancala', 0),
#  ('Murder/Mystery/Catch the Leader', 0),
#  ('Murder/Mystery/Ladder Climbing', 0),
#  ('Murder/Mystery/Delayed Purchase', 0),
#  ('Murder/Mystery/Pieces as Map', 0),
#  ('Murder/Mystery/Three Dimensional Movement', 0),
#  ('Murder/Mystery/Auction: Fixed Placement', 0),
#  ('Murder/Mystery/Constrained Bidding', 0),
#  ('Murder/Mystery/Melding and Splaying', 0),
#  ('Murder/Mystery/Multiple-Lot Auction', 0),
#  ('Murder/Mystery/Turn Order: Auction', 0),
#  ('Murder/Mystery/Multiple Maps', 0),
#  ('Murder/Mystery/Chaining', 0),
#  ('Murder/Mystery/Critical Hits and Failures', 0),
#  ('Murder/Mystery/Line of Sight', 0),
#  ('Murder/Mystery/Zone of Control', 0),
#  ('Murder/Mystery/Turn Order: Role Order', 0),
#  ('Murder/Mystery/Area-Impulse', 0),
#  ('Murder/Mystery/Once-Per-Game Abilities', 0),
#  ('Murder/Mystery/Bias', 0),
#  ('Murder/Mystery/Closed Economy Auction', 0),
#  ('Murder/Mystery/Single Loser Game', 0),
#  ('Murder/Mystery/Time Track', 0),
#  ('Murder/Mystery/I Cut, You Choose', 0),
#  ('Murder/Mystery/Line Drawing', 0),
#  ('Murder/Mystery/Different Dice Movement', 0),
#  ('Murder/Mystery/Acting', 0),
#  ('Murder/Mystery/Storytelling', 1),
#  ('Murder/Mystery/Traitor Game', 0),
#  ('Murder/Mystery/Auction: Dutch', 0),
#  ('Murder/Mystery/Lose a Turn', 0),
#  ('Murder/Mystery/Auction: Dutch Priority', 0),
#  ('Murder/Mystery/Deck Construction', 0),
#  ('Murder/Mystery/Highest-Lowest Scoring', 0),
#  ('Murder/Mystery/Rondel', 0),
#  ('Murder/Mystery/Campaign / Battle Card Driven', 0),
#  ('Murder/Mystery/Ratio / Combat Results Table', 0),
#  ('Murder/Mystery/Role Playing', 1),
#  ('Murder/Mystery/Negotiation', 0),
#  ('Murder/Mystery/Player Judge', 0),
#  ('Murder/Mystery/Die Icon Resolution', 0),
#  ('Murder/Mystery/King of the Hill', 0),
#  ('Murder/Mystery/Action/Event', 0),
#  ('Murder/Mystery/Targeted Clues', 0),
#  ('Murder/Mystery/Stacking and Balancing', 0),
#  ('Murder/Mystery/Card Play Conflict Resolution', 0),
#  ('Murder/Mystery/Speed Matching', 0),
#  ('Murder/Mystery/Narrative Choice / Paragraph', 1),
#  ('Murder/Mystery/Measurement Movement', 0),
#  ('Murder/Mystery/Movement Template', 0),
#  ('Card Game/Action Points', 3),
#  ('Card Game/Hand Management', 80),
#  ('Card Game/Memory', 12),
#  ('Card Game/Kill Steal', 2),
#  ('Card Game/Score-and-Reset Game', 7),
#  ('Card Game/Simultaneous Action Selection', 14),
#  ('Card Game/Closed Drafting', 7),
#  ('Card Game/Set Collection', 52),
#  ('Card Game/Variable Player Powers', 10),
#  ('Card Game/Layering', 3),
#  ('Card Game/Open Drafting', 32),
#  ('Card Game/Sudden Death Ending', 1),
#  ('Card Game/Tug of War', 1),
#  ('Card Game/Action Queue', 3),
#  ('Card Game/Team-Based Game', 23),
#  ('Card Game/Grid Movement', 1),
#  ('Card Game/Hexagon Grid', 0),
#  ('Card Game/Slide/Push', 0),
#  ('Card Game/Static Capture', 0),
#  ('Card Game/Deck, Bag, and Pool Building', 12),
#  ('Card Game/Auction/Bidding', 15),
#  ('Card Game/Push Your Luck', 16),
#  ('Card Game/Enclosure', 0),
#  ('Card Game/Worker Placement', 2),
#  ('Card Game/Advantage Token', 1),
#  ('Card Game/Automatic Resource Growth', 0),
#  ('Card Game/Increase Value of Unchosen Resources', 2),
#  ('Card Game/Solo / Solitaire Game', 3),
#  ('Card Game/Turn Order: Claim Action', 0),
#  ('Card Game/Tile Placement', 7),
#  ('Card Game/Area Majority / Influence', 4),
#  ('Card Game/Secret Unit Deployment', 0),
#  ('Card Game/Race', 5),
#  ('Card Game/Betting and Bluffing', 7),
#  ('Card Game/Dice Rolling', 7),
#  ('Card Game/Roll / Spin and Move', 0),
#  ('Card Game/Track Movement', 0),
#  ('Card Game/Paper-and-Pencil', 3),
#  ('Card Game/Re-rolling and Locking', 1),
#  ('Card Game/Cooperative Game', 10),
#  ('Card Game/Network and Route Building', 2),
#  ('Card Game/Hidden Roles', 4),
#  ('Card Game/Player Elimination', 8),
#  ('Card Game/Take That', 15),
#  ('Card Game/Trick-taking', 33),
#  ('Card Game/Modular Board', 2),
#  ('Card Game/Action Drafting', 0),
#  ('Card Game/Contracts', 2),
#  ('Card Game/Events', 1),
#  ('Card Game/Point to Point Movement', 1),
#  ('Card Game/Tech Trees / Tech Tracks', 1),
#  ('Card Game/Auction: Once Around', 3),
#  ('Card Game/Simulation', 2),
#  ('Card Game/Matching', 4),
#  ('Card Game/Investment', 0),
#  ('Card Game/Pattern Movement', 0),
#  ('Card Game/Square Grid', 0),
#  ('Card Game/Pick-up and Deliver', 1),
#  ('Card Game/Pattern Building', 6),
#  ('Card Game/Loans', 0),
#  ('Card Game/Map Addition', 1),
#  ('Card Game/Action Retrieval', 3),
#  ('Card Game/Area Movement', 1),
#  ('Card Game/Connections', 0),
#  ('Card Game/End Game Bonuses', 2),
#  ('Card Game/Follow', 2),
#  ('Card Game/Income', 2),
#  ('Card Game/Movement Points', 0),
#  ('Card Game/Resource to Move', 0),
#  ('Card Game/Turn Order: Progressive', 3),
#  ('Card Game/Variable Phase Order', 4),
#  ('Card Game/Worker Placement, Different Worker Types', 0),
#  ('Card Game/Grid Coverage', 0),
#  ('Card Game/Turn Order: Stat-Based', 0),
#  ('Card Game/Variable Set-up', 1),
#  ('Card Game/Worker Placement with Dice Workers', 0),
#  ('Card Game/Ownership', 0),
#  ('Card Game/Turn Order: Pass Order', 1),
#  ('Card Game/Hidden Victory Points', 2),
#  ('Card Game/Commodity Speculation', 3),
#  ('Card Game/Stock Holding', 1),
#  ('Card Game/Market', 1),
#  ('Card Game/Programmed Movement', 0),
#  ('Card Game/Command Cards', 0),
#  ('Card Game/Communication Limits', 6),
#  ('Card Game/Scenario / Mission / Campaign Game', 2),
#  ('Card Game/Voting', 2),
#  ('Card Game/Deduction', 6),
#  ('Card Game/Trading', 2),
#  ('Card Game/Move Through Deck', 0),
#  ('Card Game/Random Production', 0),
#  ('Card Game/Pattern Recognition', 2),
#  ('Card Game/Bingo', 1),
#  ('Card Game/Moving Multiple Units', 0),
#  ('Card Game/Predictive Bid', 4),
#  ('Card Game/Map Deformation', 0),
#  ('Card Game/Rock-Paper-Scissors', 1),
#  ('Card Game/Victory Points as a Resource', 2),
#  ('Card Game/Auction: Sealed Bid', 2),
#  ('Card Game/Auction: Turn Order Until Pass', 2),
#  ('Card Game/Selection Order Bid', 2),
#  ('Card Game/Map Reduction', 0),
#  ('Card Game/Mancala', 0),
#  ('Card Game/Catch the Leader', 2),
#  ('Card Game/Ladder Climbing', 3),
#  ('Card Game/Delayed Purchase', 1),
#  ('Card Game/Pieces as Map', 0),
#  ('Card Game/Three Dimensional Movement', 0),
#  ('Card Game/Auction: Fixed Placement', 0),
#  ('Card Game/Constrained Bidding', 0),
#  ('Card Game/Melding and Splaying', 1),
#  ('Card Game/Multiple-Lot Auction', 0),
#  ('Card Game/Turn Order: Auction', 0),
#  ('Card Game/Multiple Maps', 0),
#  ('Card Game/Chaining', 0),
#  ('Card Game/Critical Hits and Failures', 0),
#  ('Card Game/Line of Sight', 0),
#  ('Card Game/Zone of Control', 0),
#  ('Card Game/Turn Order: Role Order', 2),
#  ('Card Game/Area-Impulse', 0),
#  ('Card Game/Once-Per-Game Abilities', 0),
#  ('Card Game/Bias', 0),
#  ('Card Game/Closed Economy Auction', 1),
#  ('Card Game/Single Loser Game', 1),
#  ('Card Game/Time Track', 0),
#  ('Card Game/I Cut, You Choose', 0),
#  ('Card Game/Line Drawing', 0),
#  ('Card Game/Different Dice Movement', 0),
#  ('Card Game/Acting', 1),
#  ('Card Game/Storytelling', 3),
#  ('Card Game/Traitor Game', 1),
#  ('Card Game/Auction: Dutch', 2),
#  ('Card Game/Lose a Turn', 1),
#  ('Card Game/Auction: Dutch Priority', 0),
#  ('Card Game/Deck Construction', 0),
#  ('Card Game/Highest-Lowest Scoring', 1),
#  ('Card Game/Rondel', 0),
#  ('Card Game/Campaign / Battle Card Driven', 0),
#  ('Card Game/Ratio / Combat Results Table', 0),
#  ('Card Game/Role Playing', 0),
#  ('Card Game/Negotiation', 1),
#  ('Card Game/Player Judge', 1),
#  ('Card Game/Die Icon Resolution', 0),
#  ('Card Game/King of the Hill', 0),
#  ('Card Game/Action/Event', 0),
#  ('Card Game/Targeted Clues', 1),
#  ('Card Game/Stacking and Balancing', 0),
#  ('Card Game/Card Play Conflict Resolution', 0),
#  ('Card Game/Speed Matching', 1),
#  ('Card Game/Narrative Choice / Paragraph', 1),
#  ('Card Game/Measurement Movement', 0),
#  ('Card Game/Movement Template', 0),
#  ('Number/Action Points', 0),
#  ('Number/Hand Management', 4),
#  ('Number/Memory', 0),
#  ('Number/Kill Steal', 1),
#  ('Number/Score-and-Reset Game', 1),
#  ('Number/Simultaneous Action Selection', 1),
#  ('Number/Closed Drafting', 0),
#  ('Number/Set Collection', 1),
#  ('Number/Variable Player Powers', 0),
#  ('Number/Layering', 0),
#  ('Number/Open Drafting', 0),
#  ('Number/Sudden Death Ending', 0),
#  ('Number/Tug of War', 0),
#  ('Number/Action Queue', 0),
#  ('Number/Team-Based Game', 0),
#  ('Number/Grid Movement', 0),
#  ('Number/Hexagon Grid', 0),
#  ('Number/Slide/Push', 0),
#  ('Number/Static Capture', 0),
#  ('Number/Deck, Bag, and Pool Building', 0),
#  ('Number/Auction/Bidding', 0),
#  ('Number/Push Your Luck', 0),
#  ('Number/Enclosure', 0),
#  ('Number/Worker Placement', 0),
#  ('Number/Advantage Token', 0),
#  ('Number/Automatic Resource Growth', 0),
#  ('Number/Increase Value of Unchosen Resources', 0),
#  ('Number/Solo / Solitaire Game', 1),
#  ('Number/Turn Order: Claim Action', 0),
#  ('Number/Tile Placement', 2),
#  ('Number/Area Majority / Influence', 0),
#  ('Number/Secret Unit Deployment', 0),
#  ('Number/Race', 0),
#  ('Number/Betting and Bluffing', 0),
#  ('Number/Dice Rolling', 0),
#  ('Number/Roll / Spin and Move', 0),
#  ('Number/Track Movement', 0),
#  ('Number/Paper-and-Pencil', 0),
#  ('Number/Re-rolling and Locking', 0),
#  ('Number/Cooperative Game', 1),
#  ('Number/Network and Route Building', 0),
#  ('Number/Hidden Roles', 0),
#  ('Number/Player Elimination', 1),
#  ('Number/Take That', 0),
#  ('Number/Trick-taking', 0),
#  ('Number/Modular Board', 0),
#  ('Number/Action Drafting', 0),
#  ('Number/Contracts', 0),
#  ('Number/Events', 0),
#  ('Number/Point to Point Movement', 0),
#  ('Number/Tech Trees / Tech Tracks', 0),
#  ('Number/Auction: Once Around', 0),
#  ('Number/Simulation', 0),
#  ('Number/Matching', 1),
#  ('Number/Investment', 0),
#  ('Number/Pattern Movement', 0),
#  ('Number/Square Grid', 0),
#  ('Number/Pick-up and Deliver', 0),
#  ('Number/Pattern Building', 0),
#  ('Number/Loans', 0),
#  ('Number/Map Addition', 0),
#  ('Number/Action Retrieval', 0),
#  ('Number/Area Movement', 0),
#  ('Number/Connections', 0),
#  ('Number/End Game Bonuses', 0),
#  ('Number/Follow', 0),
#  ('Number/Income', 0),
#  ('Number/Movement Points', 0),
#  ('Number/Resource to Move', 0),
#  ('Number/Turn Order: Progressive', 0),
#  ('Number/Variable Phase Order', 0),
#  ('Number/Worker Placement, Different Worker Types', 0),
#  ('Number/Grid Coverage', 0),
#  ('Number/Turn Order: Stat-Based', 0),
#  ('Number/Variable Set-up', 1),
#  ('Number/Worker Placement with Dice Workers', 0),
#  ('Number/Ownership', 0),
#  ('Number/Turn Order: Pass Order', 0),
#  ('Number/Hidden Victory Points', 0),
#  ('Number/Commodity Speculation', 0),
#  ('Number/Stock Holding', 0),
#  ('Number/Market', 0),
#  ('Number/Programmed Movement', 0),
#  ('Number/Command Cards', 0),
#  ('Number/Communication Limits', 1),
#  ('Number/Scenario / Mission / Campaign Game', 0),
#  ('Number/Voting', 0),
#  ('Number/Deduction', 0),
#  ('Number/Trading', 0),
#  ('Number/Move Through Deck', 0),
#  ('Number/Random Production', 0),
#  ('Number/Pattern Recognition', 0),
#  ('Number/Bingo', 0),
#  ('Number/Moving Multiple Units', 0),
#  ('Number/Predictive Bid', 0),
#  ('Number/Map Deformation', 0),
#  ('Number/Rock-Paper-Scissors', 0),
#  ('Number/Victory Points as a Resource', 0),
#  ('Number/Auction: Sealed Bid', 0),
#  ('Number/Auction: Turn Order Until Pass', 0),
#  ('Number/Selection Order Bid', 0),
#  ('Number/Map Reduction', 0),
#  ('Number/Mancala', 0),
#  ('Number/Catch the Leader', 0),
#  ('Number/Ladder Climbing', 0),
#  ('Number/Delayed Purchase', 0),
#  ('Number/Pieces as Map', 0),
#  ('Number/Three Dimensional Movement', 0),
#  ('Number/Auction: Fixed Placement', 0),
#  ('Number/Constrained Bidding', 0),
#  ('Number/Melding and Splaying', 0),
#  ('Number/Multiple-Lot Auction', 0),
#  ('Number/Turn Order: Auction', 0),
#  ('Number/Multiple Maps', 0),
#  ('Number/Chaining', 0),
#  ('Number/Critical Hits and Failures', 0),
#  ('Number/Line of Sight', 0),
#  ('Number/Zone of Control', 0),
#  ('Number/Turn Order: Role Order', 0),
#  ('Number/Area-Impulse', 0),
#  ('Number/Once-Per-Game Abilities', 0),
#  ('Number/Bias', 0),
#  ('Number/Closed Economy Auction', 0),
#  ('Number/Single Loser Game', 0),
#  ('Number/Time Track', 0),
#  ('Number/I Cut, You Choose', 0),
#  ('Number/Line Drawing', 0),
#  ('Number/Different Dice Movement', 0),
#  ('Number/Acting', 0),
#  ('Number/Storytelling', 0),
#  ('Number/Traitor Game', 0),
#  ('Number/Auction: Dutch', 0),
#  ('Number/Lose a Turn', 0),
#  ('Number/Auction: Dutch Priority', 0),
#  ('Number/Deck Construction', 0),
#  ('Number/Highest-Lowest Scoring', 0),
#  ('Number/Rondel', 0),
#  ('Number/Campaign / Battle Card Driven', 0),
#  ('Number/Ratio / Combat Results Table', 0),
#  ('Number/Role Playing', 0),
#  ('Number/Negotiation', 0),
#  ('Number/Player Judge', 0),
#  ('Number/Die Icon Resolution', 0),
#  ('Number/King of the Hill', 0),
#  ('Number/Action/Event', 0),
#  ('Number/Targeted Clues', 0),
#  ('Number/Stacking and Balancing', 0),
#  ('Number/Card Play Conflict Resolution', 0),
#  ('Number/Speed Matching', 0),
#  ('Number/Narrative Choice / Paragraph', 0),
#  ('Number/Measurement Movement', 0),
#  ('Number/Movement Template', 0),
#  ('Ancient/Action Points', 1),
#  ('Ancient/Hand Management', 9),
#  ('Ancient/Memory', 1),
#  ('Ancient/Kill Steal', 0),
#  ('Ancient/Score-and-Reset Game', 0),
#  ('Ancient/Simultaneous Action Selection', 2),
#  ('Ancient/Closed Drafting', 1),
#  ('Ancient/Set Collection', 9),
#  ('Ancient/Variable Player Powers', 3),
#  ('Ancient/Layering', 2),
#  ('Ancient/Open Drafting', 7),
#  ('Ancient/Sudden Death Ending', 1),
#  ('Ancient/Tug of War', 1),
#  ('Ancient/Action Queue', 0),
#  ('Ancient/Team-Based Game', 2),
#  ('Ancient/Grid Movement', 1),
#  ('Ancient/Hexagon Grid', 1),
#  ('Ancient/Slide/Push', 0),
#  ('Ancient/Static Capture', 0),
#  ('Ancient/Deck, Bag, and Pool Building', 2),
#  ('Ancient/Auction/Bidding', 1),
#  ('Ancient/Push Your Luck', 1),
#  ('Ancient/Enclosure', 0),
#  ('Ancient/Worker Placement', 3),
#  ('Ancient/Advantage Token', 1),
#  ('Ancient/Automatic Resource Growth', 0),
#  ('Ancient/Increase Value of Unchosen Resources', 0),
#  ('Ancient/Solo / Solitaire Game', 1),
#  ('Ancient/Turn Order: Claim Action', 1),
#  ('Ancient/Tile Placement', 3),
#  ('Ancient/Area Majority / Influence', 3),
#  ('Ancient/Secret Unit Deployment', 0),
#  ('Ancient/Race', 3),
#  ('Ancient/Betting and Bluffing', 0),
#  ('Ancient/Dice Rolling', 3),
#  ('Ancient/Roll / Spin and Move', 1),
#  ('Ancient/Track Movement', 2),
#  ('Ancient/Paper-and-Pencil', 0),
#  ('Ancient/Re-rolling and Locking', 0),
#  ('Ancient/Cooperative Game', 1),
#  ('Ancient/Network and Route Building', 0),
#  ('Ancient/Hidden Roles', 0),
#  ('Ancient/Player Elimination', 1),
#  ('Ancient/Take That', 0),
#  ('Ancient/Trick-taking', 0),
#  ('Ancient/Modular Board', 2),
#  ('Ancient/Action Drafting', 0),
#  ('Ancient/Contracts', 0),
#  ('Ancient/Events', 0),
#  ('Ancient/Point to Point Movement', 0),
#  ('Ancient/Tech Trees / Tech Tracks', 0),
#  ('Ancient/Auction: Once Around', 0),
#  ('Ancient/Simulation', 2),
#  ('Ancient/Matching', 0),
#  ('Ancient/Investment', 0),
#  ('Ancient/Pattern Movement', 0),
#  ('Ancient/Square Grid', 1),
#  ('Ancient/Pick-up and Deliver', 0),
#  ('Ancient/Pattern Building', 1),
#  ('Ancient/Loans', 1),
#  ('Ancient/Map Addition', 0),
#  ('Ancient/Action Retrieval', 0),
#  ('Ancient/Area Movement', 2),
#  ('Ancient/Connections', 0),
#  ('Ancient/End Game Bonuses', 3),
#  ('Ancient/Follow', 0),
#  ('Ancient/Income', 0),
#  ('Ancient/Movement Points', 0),
#  ('Ancient/Resource to Move', 0),
#  ('Ancient/Turn Order: Progressive', 0),
#  ('Ancient/Variable Phase Order', 1),
#  ('Ancient/Worker Placement, Different Worker Types', 0),
#  ('Ancient/Grid Coverage', 0),
#  ('Ancient/Turn Order: Stat-Based', 0),
#  ('Ancient/Variable Set-up', 2),
#  ('Ancient/Worker Placement with Dice Workers', 1),
#  ('Ancient/Ownership', 0),
#  ('Ancient/Turn Order: Pass Order', 0),
#  ('Ancient/Hidden Victory Points', 0),
#  ('Ancient/Commodity Speculation', 2),
#  ('Ancient/Stock Holding', 1),
#  ('Ancient/Market', 0),
#  ('Ancient/Programmed Movement', 0),
#  ('Ancient/Command Cards', 0),
#  ('Ancient/Communication Limits', 0),
#  ('Ancient/Scenario / Mission / Campaign Game', 0),
#  ('Ancient/Voting', 0),
#  ('Ancient/Deduction', 0),
#  ('Ancient/Trading', 0),
#  ('Ancient/Move Through Deck', 0),
#  ('Ancient/Random Production', 1),
#  ('Ancient/Pattern Recognition', 0),
#  ('Ancient/Bingo', 0),
#  ('Ancient/Moving Multiple Units', 0),
#  ('Ancient/Predictive Bid', 0),
#  ('Ancient/Map Deformation', 0),
#  ('Ancient/Rock-Paper-Scissors', 0),
#  ('Ancient/Victory Points as a Resource', 1),
#  ('Ancient/Auction: Sealed Bid', 0),
#  ('Ancient/Auction: Turn Order Until Pass', 0),
#  ('Ancient/Selection Order Bid', 0),
#  ('Ancient/Map Reduction', 0),
#  ('Ancient/Mancala', 1),
#  ('Ancient/Catch the Leader', 0),
#  ('Ancient/Ladder Climbing', 0),
#  ('Ancient/Delayed Purchase', 0),
#  ('Ancient/Pieces as Map', 0),
#  ('Ancient/Three Dimensional Movement', 1),
#  ('Ancient/Auction: Fixed Placement', 0),
#  ('Ancient/Constrained Bidding', 0),
#  ('Ancient/Melding and Splaying', 0),
#  ('Ancient/Multiple-Lot Auction', 0),
#  ('Ancient/Turn Order: Auction', 0),
#  ('Ancient/Multiple Maps', 0),
#  ('Ancient/Chaining', 0),
#  ('Ancient/Critical Hits and Failures', 0),
#  ('Ancient/Line of Sight', 0),
#  ('Ancient/Zone of Control', 0),
#  ('Ancient/Turn Order: Role Order', 0),
#  ('Ancient/Area-Impulse', 0),
#  ('Ancient/Once-Per-Game Abilities', 0),
#  ('Ancient/Bias', 1),
#  ('Ancient/Closed Economy Auction', 0),
#  ('Ancient/Single Loser Game', 0),
#  ('Ancient/Time Track', 0),
#  ('Ancient/I Cut, You Choose', 0),
#  ('Ancient/Line Drawing', 0),
#  ('Ancient/Different Dice Movement', 0),
#  ('Ancient/Acting', 0),
#  ('Ancient/Storytelling', 0),
#  ('Ancient/Traitor Game', 0),
#  ('Ancient/Auction: Dutch', 1),
#  ('Ancient/Lose a Turn', 0),
#  ('Ancient/Auction: Dutch Priority', 0),
#  ('Ancient/Deck Construction', 0),
#  ('Ancient/Highest-Lowest Scoring', 0),
#  ('Ancient/Rondel', 1),
#  ('Ancient/Campaign / Battle Card Driven', 1),
#  ('Ancient/Ratio / Combat Results Table', 0),
#  ('Ancient/Role Playing', 0),
#  ('Ancient/Negotiation', 0),
#  ('Ancient/Player Judge', 0),
#  ('Ancient/Die Icon Resolution', 0),
#  ('Ancient/King of the Hill', 0),
#  ('Ancient/Action/Event', 0),
#  ('Ancient/Targeted Clues', 0),
#  ('Ancient/Stacking and Balancing', 0),
#  ('Ancient/Card Play Conflict Resolution', 0),
#  ('Ancient/Speed Matching', 0),
#  ('Ancient/Narrative Choice / Paragraph', 0),
#  ('Ancient/Measurement Movement', 0),
#  ('Ancient/Movement Template', 0),
#  ('City Building/Action Points', 2),
#  ('City Building/Hand Management', 5),
#  ('City Building/Memory', 1),
#  ('City Building/Kill Steal', 0),
#  ('City Building/Score-and-Reset Game', 0),
#  ('City Building/Simultaneous Action Selection', 2),
#  ('City Building/Closed Drafting', 1),
#  ('City Building/Set Collection', 9),
#  ('City Building/Variable Player Powers', 1),
#  ('City Building/Layering', 1),
#  ('City Building/Open Drafting', 9),
#  ('City Building/Sudden Death Ending', 1),
#  ('City Building/Tug of War', 1),
#  ('City Building/Action Queue', 1),
#  ('City Building/Team-Based Game', 0),
#  ('City Building/Grid Movement', 0),
#  ('City Building/Hexagon Grid', 1),
#  ('City Building/Slide/Push', 0),
#  ('City Building/Static Capture', 0),
#  ('City Building/Deck, Bag, and Pool Building', 1),
#  ('City Building/Auction/Bidding', 2),
#  ('City Building/Push Your Luck', 0),
#  ('City Building/Enclosure', 0),
#  ('City Building/Worker Placement', 4),
#  ('City Building/Advantage Token', 0),
#  ('City Building/Automatic Resource Growth', 0),
#  ('City Building/Increase Value of Unchosen Resources', 1),
#  ('City Building/Solo / Solitaire Game', 2),
#  ('City Building/Turn Order: Claim Action', 1),
#  ('City Building/Tile Placement', 10),
#  ('City Building/Area Majority / Influence', 3),
#  ('City Building/Secret Unit Deployment', 0),
#  ('City Building/Race', 0),
#  ('City Building/Betting and Bluffing', 0),
#  ('City Building/Dice Rolling', 0),
#  ('City Building/Roll / Spin and Move', 0),
#  ('City Building/Track Movement', 0),
#  ('City Building/Paper-and-Pencil', 2),
#  ('City Building/Re-rolling and Locking', 0),
#  ('City Building/Cooperative Game', 0),
#  ('City Building/Network and Route Building', 2),
#  ('City Building/Hidden Roles', 0),
#  ('City Building/Player Elimination', 0),
#  ('City Building/Take That', 0),
#  ('City Building/Trick-taking', 0),
#  ('City Building/Modular Board', 2),
#  ('City Building/Action Drafting', 1),
#  ('City Building/Contracts', 2),
#  ('City Building/Events', 1),
#  ('City Building/Point to Point Movement', 0),
#  ('City Building/Tech Trees / Tech Tracks', 0),
#  ('City Building/Auction: Once Around', 0),
#  ('City Building/Simulation', 0),
#  ('City Building/Matching', 0),
#  ('City Building/Investment', 0),
#  ('City Building/Pattern Movement', 0),
#  ('City Building/Square Grid', 2),
#  ('City Building/Pick-up and Deliver', 0),
#  ('City Building/Pattern Building', 3),
#  ('City Building/Loans', 2),
#  ('City Building/Map Addition', 1),
#  ('City Building/Action Retrieval', 0),
#  ('City Building/Area Movement', 0),
#  ('City Building/Connections', 0),
#  ('City Building/End Game Bonuses', 2),
#  ('City Building/Follow', 1),
#  ('City Building/Income', 4),
#  ('City Building/Movement Points', 0),
#  ('City Building/Resource to Move', 0),
#  ('City Building/Turn Order: Progressive', 1),
#  ('City Building/Variable Phase Order', 1),
#  ('City Building/Worker Placement, Different Worker Types', 1),
#  ('City Building/Grid Coverage', 2),
#  ('City Building/Turn Order: Stat-Based', 1),
#  ('City Building/Variable Set-up', 2),
#  ('City Building/Worker Placement with Dice Workers', 0),
#  ('City Building/Ownership', 2),
#  ('City Building/Turn Order: Pass Order', 1),
#  ('City Building/Hidden Victory Points', 1),
#  ('City Building/Commodity Speculation', 0),
#  ('City Building/Stock Holding', 0),
#  ('City Building/Market', 1),
#  ('City Building/Programmed Movement', 0),
#  ('City Building/Command Cards', 0),
#  ('City Building/Communication Limits', 0),
#  ('City Building/Scenario / Mission / Campaign Game', 0),
#  ('City Building/Voting', 0),
#  ('City Building/Deduction', 0),
#  ...]

# %%
df_combination=pd.DataFrame(combination, columns=['Category/Mechanic','Number_of_games'])

# %%
df_combination.sort_values('Number_of_games',ascending=False)[:15].style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d94e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Category/Mechanic</th>
#       <th class="col_heading level0 col1" >Number_of_games</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d94e_row0_col0" class="data row0 col0" >Card Game/Hand Management</td>
#       <td id="T_9d94e_row0_col1" class="data row0 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row1_col0" class="data row1 col0" >Card Game/Set Collection</td>
#       <td id="T_9d94e_row1_col1" class="data row1 col1" >52</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row2_col0" class="data row2 col0" >Dice/Dice Rolling</td>
#       <td id="T_9d94e_row2_col1" class="data row2 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row3_col0" class="data row3 col0" >Card Game/Trick-taking</td>
#       <td id="T_9d94e_row3_col1" class="data row3 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row4_col0" class="data row4 col0" >Card Game/Open Drafting</td>
#       <td id="T_9d94e_row4_col1" class="data row4 col1" >32</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row5_col0" class="data row5 col0" >Abstract Strategy/Grid Movement</td>
#       <td id="T_9d94e_row5_col1" class="data row5 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row6_col0" class="data row6 col0" >Abstract Strategy/Pattern Building</td>
#       <td id="T_9d94e_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row7_col0" class="data row7 col0" >Card Game/Team-Based Game</td>
#       <td id="T_9d94e_row7_col1" class="data row7 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row8_col0" class="data row8 col0" >Abstract Strategy/Tile Placement</td>
#       <td id="T_9d94e_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row9_col0" class="data row9 col0" >Fantasy/Hand Management</td>
#       <td id="T_9d94e_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row10_col0" class="data row10 col0" >Economic/Set Collection</td>
#       <td id="T_9d94e_row10_col1" class="data row10 col1" >18</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row11_col0" class="data row11 col0" >Card Game/Push Your Luck</td>
#       <td id="T_9d94e_row11_col1" class="data row11 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row12_col0" class="data row12 col0" >Fantasy/Open Drafting</td>
#       <td id="T_9d94e_row12_col1" class="data row12 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row13_col0" class="data row13 col0" >Abstract Strategy/Square Grid</td>
#       <td id="T_9d94e_row13_col1" class="data row13 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_9d94e_row14_col0" class="data row14 col0" >Card Game/Take That</td>
#       <td id="T_9d94e_row14_col1" class="data row14 col1" >15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The most popular combination is category "Card Name" and mechanic "Hand Management".

# %% [markdown]
# We save the modified data.

# %%
df.to_csv('boardgames.csv',index=False)
